# %%
import os
import json
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import  MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.utils.class_weight import compute_class_weight

# %%
# Set random seed for reproducibility
tf.random.set_seed(42)
np.random.seed(42)

# %% [markdown]
# # **Data Augmentation Pipeline And Dataset Info :**

# %%
def data_aug(train_dir, val_dir, test_dir, validation_split=0.0):
    
    # Check the directories are exist or not 
    for dir in [train_dir, val_dir, test_dir]:
        if not os.path.exists(dir):
            print(f"Warning: No directory [{dir}] is found.")
    
    # Define data augmentation pipeline 
    train_datagen = ImageDataGenerator(preprocessing_function = tf.keras.applications.mobilenet_v2.preprocess_input, 
                                       rotation_range=25,
                                       width_shift_range=0.2,
                                       height_shift_range=0.2,
                                       horizontal_flip=True,
                                       zoom_range=0.2,
                                       brightness_range=[0.8,1.2],
                                       shear_range=0.15,
                                       fill_mode='nearest',
                                       validation_split=validation_split if not val_dir else 0.0)
    
    val_datagen = ImageDataGenerator(preprocessing_function = tf.keras.applications.mobilenet_v2.preprocess_input,
                                     validation_split=validation_split if not val_dir else 0.0)
    
    # Create data generators based on available directories
    if val_dir and test_dir:
        try:
            train_gen = train_datagen.flow_from_directory(train_dir, target_size=(224, 224), batch_size=32, class_mode='categorical', shuffle=True)
            print("Successfully created Train Generator.")
        except Exception as e:
            print(f"Error occurred during create Train Generator: {e}")
        
        try:
            val_gen = val_datagen.flow_from_directory(val_dir, target_size=(224, 224), batch_size=32, class_mode='categorical', shuffle=True)
            print("Successfully created Validation Generator.")
        except Exception as e:
            print(f"Error occurred during create Validation Generator: {e}")
        
        try:
            test_gen = val_datagen.flow_from_directory(test_dir, target_size=(224, 224), batch_size=32, class_mode='categorical', shuffle=True)
            print("Successfully created Test Generator.")
        except Exception as e:
            print(f"Error occurred during create Test Generator: {e}")
    
    else:
        try:
            train_gen = train_datagen.flow_from_directory(train_dir, target_size=(224, 224), batch_size=32, class_mode='categorical', shuffle=True, subset='training')
            print("Successfully created Train Generator.")
        except Exception as e:
            print(f"Error occurred during create Train Generator: {e}")
        
        try:
            val_gen = val_datagen.flow_from_directory(train_dir, target_size=(224, 224), batch_size=32, class_mode='categorical', shuffle=True, subset='validation')
            print("Successfully created Validation Generator.")
        except Exception as e:
            print(f"Error occurred during create Validation Generator: {e}")
        
        try:
            # Use validation set as test set if no separate test set 
            test_gen = val_gen
            print("Successfully created Test Generator.")
        except Exception as e:
            print(f"Error occurred during create Test Generator: {e}")
    
    return train_gen , val_gen, test_gen

# %%
train_gen , val_gen, test_gen = data_aug(train_dir='/kaggle/input/skin-diseases-splited-dataset/train', 
                                         val_dir='/kaggle/input/skin-diseases-splited-dataset/val', 
                                         test_dir='/kaggle/input/skin-diseases-splited-dataset/val', 
                                         validation_split=0.0)
# Out:
# Found 1640 images belonging to 6 classes.
# Successfully created Train Generator.
# Found 620 images belonging to 6 classes.
# Successfully created Validation Generator.
# Found 620 images belonging to 6 classes.
# Successfully created Test Generator.

# %% [markdown]
# #### **Dataset Information :**

# %%
print(f"Training samples: [{train_gen.samples}]")
print(f"Validation samples: [{val_gen.samples}]")
print(f"Test samples: [{test_gen.samples}]")
print(f"Number of classes: [{len(train_gen.class_indices)}]")
print(f"Class names: {list(train_gen.class_indices.keys())}")
# Out:
# Training samples: [1640]
# Validation samples: [620]
# Test samples: [620]
# Number of classes: [6]
# Class names: ['Chickenpox', 'Cowpox', 'HFMD', 'Healthy', 'Measles', 'Monkeypox']

# %% [markdown]
# #### **Plot Function To See Class Distributions :**

# %%
def cls_dis(any_generator, set_name):
     
    cls_counts = np.bincount(any_generator.classes) 
    cls_labels = list(any_generator.class_indices.keys())
    
    plt.figure(figsize=(10,5))
    bars = plt.bar(cls_labels, cls_counts, color='Skyblue', edgecolor='black', alpha=0.7)
    plt.title(f'Class Distribution in {set_name}', fontsize=14, fontweight='bold')
    plt.xlabel('Disease Classes', fontsize=12, fontweight='bold')  
    plt.ylabel('Number of Images', fontsize=12, fontweight='bold')
    plt.xticks(rotation=45, ha='right')
    
    # Add value labels on bars 
    for bar, count in zip(bars, cls_counts):
        plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(), str(count), ha='center',
                 va='bottom', fontweight='bold')  
    
    plt.tight_layout()
    plt.show()

# %%
cls_dis(any_generator=train_gen, set_name='Training Set')

# %%
cls_dis(any_generator=val_gen, set_name='Validation Set')

# %%
# We use val set as test set
cls_dis(any_generator=val_gen, set_name='Test Set')

# %% [markdown]
# # **Create The Model With 'MobileNetV2' Base And Custom Classification Head :**

# %%
def create_model():
    base_model = MobileNetV2(weights='imagenet',
                             include_top=False,
                             input_shape=(224,224,3))
    
    # Freeze the bas model layers (If we want transfer learning)
    base_model.trainable = False
    
    # Custom Classification Head
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(1024, activation='relu', dtype='float32')(x)
    x = Dropout(0.5)(x)
    x = Dense(512, activation='relu', dtype='float32')(x)
    x = Dropout(0.4)(x)
    x = Dense(256, activation='relu', dtype='float32')(x)
    x = Dropout(0.3)(x)
    x = Dense(128, activation='relu', dtype='float32')(x)
    x = Dropout(0.2)(x)
    predictions = Dense(6, activation='softmax', dtype='float32', name='predictions')(x)    # Number of classes in the dataset is [6]
    
    new_model = Model(inputs=base_model.input, outputs=predictions)
    
    return new_model , base_model

# %%
new_model , base_model = create_model()

# %%
new_model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1 (Conv2D)            │ (None, 112, 112, 32)   │            864 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn_Conv1                  │ (None, 112, 112, 32)   │            128 │ Conv1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1_relu (ReLU)         │ (None, 112, 112, 32)   │              0 │ bn_Conv1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise   │ (None, 112, 112, 32)   │            288 │ Conv1_relu[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │            128 │ expanded_conv_depthwi… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │              0 │ expanded_conv_depthwi… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project     │ (None, 112, 112, 16)   │            512 │ expanded_conv_depthwi… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project_BN  │ (None, 112, 112, 16)   │             64 │ expanded_conv_project… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand (Conv2D)   │ (None, 112, 112, 96)   │          1,536 │ expanded_conv_project… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_BN         │ (None, 112, 112, 96)   │            384 │ block_1_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_relu       │ (None, 112, 112, 96)   │              0 │ block_1_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_pad               │ (None, 113, 113, 96)   │              0 │ block_1_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise         │ (None, 56, 56, 96)     │            864 │ block_1_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_BN      │ (None, 56, 56, 96)     │            384 │ block_1_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_relu    │ (None, 56, 56, 96)     │              0 │ block_1_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project (Conv2D)  │ (None, 56, 56, 24)     │          2,304 │ block_1_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project_BN        │ (None, 56, 56, 24)     │             96 │ block_1_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_1_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_2_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_2_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise         │ (None, 56, 56, 144)    │          1,296 │ block_2_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_BN      │ (None, 56, 56, 144)    │            576 │ block_2_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_relu    │ (None, 56, 56, 144)    │              0 │ block_2_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project (Conv2D)  │ (None, 56, 56, 24)     │          3,456 │ block_2_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project_BN        │ (None, 56, 56, 24)     │             96 │ block_2_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_add (Add)         │ (None, 56, 56, 24)     │              0 │ block_1_project_BN[0]… │
# │                           │                        │                │ block_2_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_2_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_3_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_3_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_pad               │ (None, 57, 57, 144)    │              0 │ block_3_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise         │ (None, 28, 28, 144)    │          1,296 │ block_3_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_BN      │ (None, 28, 28, 144)    │            576 │ block_3_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_relu    │ (None, 28, 28, 144)    │              0 │ block_3_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project (Conv2D)  │ (None, 28, 28, 32)     │          4,608 │ block_3_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project_BN        │ (None, 28, 28, 32)     │            128 │ block_3_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_3_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_4_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_4_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_4_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_4_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_4_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_4_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project_BN        │ (None, 28, 28, 32)     │            128 │ block_4_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_3_project_BN[0]… │
# │                           │                        │                │ block_4_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_4_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_5_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_5_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_5_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_5_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_5_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_5_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project_BN        │ (None, 28, 28, 32)     │            128 │ block_5_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_4_add[0][0],     │
# │                           │                        │                │ block_5_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_5_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_6_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_6_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_pad               │ (None, 29, 29, 192)    │              0 │ block_6_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise         │ (None, 14, 14, 192)    │          1,728 │ block_6_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_BN      │ (None, 14, 14, 192)    │            768 │ block_6_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_relu    │ (None, 14, 14, 192)    │              0 │ block_6_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project (Conv2D)  │ (None, 14, 14, 64)     │         12,288 │ block_6_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project_BN        │ (None, 14, 14, 64)     │            256 │ block_6_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_6_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_7_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_7_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_7_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_7_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_7_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_7_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project_BN        │ (None, 14, 14, 64)     │            256 │ block_7_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_6_project_BN[0]… │
# │                           │                        │                │ block_7_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_7_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_8_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_8_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_8_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_8_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_8_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_8_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project_BN        │ (None, 14, 14, 64)     │            256 │ block_8_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_7_add[0][0],     │
# │                           │                        │                │ block_8_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_8_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_9_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_9_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_9_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_9_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_9_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_9_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project_BN        │ (None, 14, 14, 64)     │            256 │ block_9_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_8_add[0][0],     │
# │                           │                        │                │ block_9_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand (Conv2D)  │ (None, 14, 14, 384)    │         24,576 │ block_9_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_BN        │ (None, 14, 14, 384)    │          1,536 │ block_10_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_relu      │ (None, 14, 14, 384)    │              0 │ block_10_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise        │ (None, 14, 14, 384)    │          3,456 │ block_10_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_BN     │ (None, 14, 14, 384)    │          1,536 │ block_10_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_relu   │ (None, 14, 14, 384)    │              0 │ block_10_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project (Conv2D) │ (None, 14, 14, 96)     │         36,864 │ block_10_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project_BN       │ (None, 14, 14, 96)     │            384 │ block_10_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_10_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_11_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_11_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_11_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_11_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_11_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_11_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project_BN       │ (None, 14, 14, 96)     │            384 │ block_11_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_10_project_BN[0… │
# │                           │                        │                │ block_11_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_11_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_12_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_12_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_12_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_12_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_12_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_12_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project_BN       │ (None, 14, 14, 96)     │            384 │ block_12_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_11_add[0][0],    │
# │                           │                        │                │ block_12_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_12_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_13_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_13_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_pad              │ (None, 15, 15, 576)    │              0 │ block_13_expand_relu[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise        │ (None, 7, 7, 576)      │          5,184 │ block_13_pad[0][0]     │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_BN     │ (None, 7, 7, 576)      │          2,304 │ block_13_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_relu   │ (None, 7, 7, 576)      │              0 │ block_13_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project (Conv2D) │ (None, 7, 7, 160)      │         92,160 │ block_13_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project_BN       │ (None, 7, 7, 160)      │            640 │ block_13_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_13_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_14_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_14_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_14_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_14_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_14_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_14_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project_BN       │ (None, 7, 7, 160)      │            640 │ block_14_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_13_project_BN[0… │
# │                           │                        │                │ block_14_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_14_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_15_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_15_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_15_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_15_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_15_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_15_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project_BN       │ (None, 7, 7, 160)      │            640 │ block_15_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_14_add[0][0],    │
# │                           │                        │                │ block_15_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_15_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_16_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_16_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_16_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_16_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_16_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project (Conv2D) │ (None, 7, 7, 320)      │        307,200 │ block_16_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project_BN       │ (None, 7, 7, 320)      │          1,280 │ block_16_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1 (Conv2D)           │ (None, 7, 7, 1280)     │        409,600 │ block_16_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1_bn                 │ (None, 7, 7, 1280)     │          5,120 │ Conv_1[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ out_relu (ReLU)           │ (None, 7, 7, 1280)     │              0 │ Conv_1_bn[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 1280)           │              0 │ out_relu[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_1     │ (None, 1280)           │          5,120 │ global_average_poolin… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 1024)           │      1,311,744 │ batch_normalization_1… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_4 (Dropout)       │ (None, 1024)           │              0 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 512)            │        524,800 │ dropout_4[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_5 (Dropout)       │ (None, 512)            │              0 │ dense_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 256)            │        131,328 │ dropout_5[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_6 (Dropout)       │ (None, 256)            │              0 │ dense_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_7 (Dense)           │ (None, 128)            │         32,896 │ dropout_6[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 128)            │              0 │ dense_7[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ predictions (Dense)       │ (None, 6)              │            774 │ dropout_7[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 4,264,646 (16.27 MB)
#  Trainable params: 2,004,102 (7.65 MB)
#  Non-trainable params: 2,260,544 (8.62 MB)

# %%
base_model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 224, 224, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1 (Conv2D)            │ (None, 112, 112, 32)   │            864 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ bn_Conv1                  │ (None, 112, 112, 32)   │            128 │ Conv1[0][0]            │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv1_relu (ReLU)         │ (None, 112, 112, 32)   │              0 │ bn_Conv1[0][0]         │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise   │ (None, 112, 112, 32)   │            288 │ Conv1_relu[0][0]       │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │            128 │ expanded_conv_depthwi… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_depthwise_… │ (None, 112, 112, 32)   │              0 │ expanded_conv_depthwi… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project     │ (None, 112, 112, 16)   │            512 │ expanded_conv_depthwi… │
# │ (Conv2D)                  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ expanded_conv_project_BN  │ (None, 112, 112, 16)   │             64 │ expanded_conv_project… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand (Conv2D)   │ (None, 112, 112, 96)   │          1,536 │ expanded_conv_project… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_BN         │ (None, 112, 112, 96)   │            384 │ block_1_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_expand_relu       │ (None, 112, 112, 96)   │              0 │ block_1_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_pad               │ (None, 113, 113, 96)   │              0 │ block_1_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise         │ (None, 56, 56, 96)     │            864 │ block_1_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_BN      │ (None, 56, 56, 96)     │            384 │ block_1_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_depthwise_relu    │ (None, 56, 56, 96)     │              0 │ block_1_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project (Conv2D)  │ (None, 56, 56, 24)     │          2,304 │ block_1_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_1_project_BN        │ (None, 56, 56, 24)     │             96 │ block_1_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_1_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_2_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_2_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise         │ (None, 56, 56, 144)    │          1,296 │ block_2_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_BN      │ (None, 56, 56, 144)    │            576 │ block_2_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_depthwise_relu    │ (None, 56, 56, 144)    │              0 │ block_2_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project (Conv2D)  │ (None, 56, 56, 24)     │          3,456 │ block_2_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_project_BN        │ (None, 56, 56, 24)     │             96 │ block_2_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_2_add (Add)         │ (None, 56, 56, 24)     │              0 │ block_1_project_BN[0]… │
# │                           │                        │                │ block_2_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand (Conv2D)   │ (None, 56, 56, 144)    │          3,456 │ block_2_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_BN         │ (None, 56, 56, 144)    │            576 │ block_3_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_expand_relu       │ (None, 56, 56, 144)    │              0 │ block_3_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_pad               │ (None, 57, 57, 144)    │              0 │ block_3_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise         │ (None, 28, 28, 144)    │          1,296 │ block_3_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_BN      │ (None, 28, 28, 144)    │            576 │ block_3_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_depthwise_relu    │ (None, 28, 28, 144)    │              0 │ block_3_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project (Conv2D)  │ (None, 28, 28, 32)     │          4,608 │ block_3_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_3_project_BN        │ (None, 28, 28, 32)     │            128 │ block_3_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_3_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_4_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_4_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_4_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_4_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_4_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_4_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_project_BN        │ (None, 28, 28, 32)     │            128 │ block_4_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_4_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_3_project_BN[0]… │
# │                           │                        │                │ block_4_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_4_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_5_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_5_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise         │ (None, 28, 28, 192)    │          1,728 │ block_5_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_BN      │ (None, 28, 28, 192)    │            768 │ block_5_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_depthwise_relu    │ (None, 28, 28, 192)    │              0 │ block_5_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project (Conv2D)  │ (None, 28, 28, 32)     │          6,144 │ block_5_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_project_BN        │ (None, 28, 28, 32)     │            128 │ block_5_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_5_add (Add)         │ (None, 28, 28, 32)     │              0 │ block_4_add[0][0],     │
# │                           │                        │                │ block_5_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand (Conv2D)   │ (None, 28, 28, 192)    │          6,144 │ block_5_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_BN         │ (None, 28, 28, 192)    │            768 │ block_6_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_expand_relu       │ (None, 28, 28, 192)    │              0 │ block_6_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_pad               │ (None, 29, 29, 192)    │              0 │ block_6_expand_relu[0… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise         │ (None, 14, 14, 192)    │          1,728 │ block_6_pad[0][0]      │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_BN      │ (None, 14, 14, 192)    │            768 │ block_6_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_depthwise_relu    │ (None, 14, 14, 192)    │              0 │ block_6_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project (Conv2D)  │ (None, 14, 14, 64)     │         12,288 │ block_6_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_6_project_BN        │ (None, 14, 14, 64)     │            256 │ block_6_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_6_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_7_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_7_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_7_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_7_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_7_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_7_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_project_BN        │ (None, 14, 14, 64)     │            256 │ block_7_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_7_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_6_project_BN[0]… │
# │                           │                        │                │ block_7_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_7_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_8_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_8_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_8_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_8_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_8_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_8_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_project_BN        │ (None, 14, 14, 64)     │            256 │ block_8_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_8_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_7_add[0][0],     │
# │                           │                        │                │ block_8_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand (Conv2D)   │ (None, 14, 14, 384)    │         24,576 │ block_8_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_BN         │ (None, 14, 14, 384)    │          1,536 │ block_9_expand[0][0]   │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_expand_relu       │ (None, 14, 14, 384)    │              0 │ block_9_expand_BN[0][… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise         │ (None, 14, 14, 384)    │          3,456 │ block_9_expand_relu[0… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_BN      │ (None, 14, 14, 384)    │          1,536 │ block_9_depthwise[0][… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_depthwise_relu    │ (None, 14, 14, 384)    │              0 │ block_9_depthwise_BN[… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project (Conv2D)  │ (None, 14, 14, 64)     │         24,576 │ block_9_depthwise_rel… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_project_BN        │ (None, 14, 14, 64)     │            256 │ block_9_project[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_9_add (Add)         │ (None, 14, 14, 64)     │              0 │ block_8_add[0][0],     │
# │                           │                        │                │ block_9_project_BN[0]… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand (Conv2D)  │ (None, 14, 14, 384)    │         24,576 │ block_9_add[0][0]      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_BN        │ (None, 14, 14, 384)    │          1,536 │ block_10_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_expand_relu      │ (None, 14, 14, 384)    │              0 │ block_10_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise        │ (None, 14, 14, 384)    │          3,456 │ block_10_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_BN     │ (None, 14, 14, 384)    │          1,536 │ block_10_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_depthwise_relu   │ (None, 14, 14, 384)    │              0 │ block_10_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project (Conv2D) │ (None, 14, 14, 96)     │         36,864 │ block_10_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_10_project_BN       │ (None, 14, 14, 96)     │            384 │ block_10_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_10_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_11_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_11_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_11_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_11_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_11_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_11_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_project_BN       │ (None, 14, 14, 96)     │            384 │ block_11_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_11_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_10_project_BN[0… │
# │                           │                        │                │ block_11_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_11_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_12_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_12_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise        │ (None, 14, 14, 576)    │          5,184 │ block_12_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_BN     │ (None, 14, 14, 576)    │          2,304 │ block_12_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_depthwise_relu   │ (None, 14, 14, 576)    │              0 │ block_12_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project (Conv2D) │ (None, 14, 14, 96)     │         55,296 │ block_12_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_project_BN       │ (None, 14, 14, 96)     │            384 │ block_12_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_12_add (Add)        │ (None, 14, 14, 96)     │              0 │ block_11_add[0][0],    │
# │                           │                        │                │ block_12_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand (Conv2D)  │ (None, 14, 14, 576)    │         55,296 │ block_12_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_BN        │ (None, 14, 14, 576)    │          2,304 │ block_13_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_expand_relu      │ (None, 14, 14, 576)    │              0 │ block_13_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_pad              │ (None, 15, 15, 576)    │              0 │ block_13_expand_relu[… │
# │ (ZeroPadding2D)           │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise        │ (None, 7, 7, 576)      │          5,184 │ block_13_pad[0][0]     │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_BN     │ (None, 7, 7, 576)      │          2,304 │ block_13_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_depthwise_relu   │ (None, 7, 7, 576)      │              0 │ block_13_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project (Conv2D) │ (None, 7, 7, 160)      │         92,160 │ block_13_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_13_project_BN       │ (None, 7, 7, 160)      │            640 │ block_13_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_13_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_14_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_14_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_14_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_14_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_14_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_14_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_project_BN       │ (None, 7, 7, 160)      │            640 │ block_14_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_14_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_13_project_BN[0… │
# │                           │                        │                │ block_14_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_14_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_15_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_15_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_15_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_15_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_15_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project (Conv2D) │ (None, 7, 7, 160)      │        153,600 │ block_15_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_project_BN       │ (None, 7, 7, 160)      │            640 │ block_15_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_15_add (Add)        │ (None, 7, 7, 160)      │              0 │ block_14_add[0][0],    │
# │                           │                        │                │ block_15_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand (Conv2D)  │ (None, 7, 7, 960)      │        153,600 │ block_15_add[0][0]     │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_BN        │ (None, 7, 7, 960)      │          3,840 │ block_16_expand[0][0]  │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_expand_relu      │ (None, 7, 7, 960)      │              0 │ block_16_expand_BN[0]… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise        │ (None, 7, 7, 960)      │          8,640 │ block_16_expand_relu[… │
# │ (DepthwiseConv2D)         │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_BN     │ (None, 7, 7, 960)      │          3,840 │ block_16_depthwise[0]… │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_depthwise_relu   │ (None, 7, 7, 960)      │              0 │ block_16_depthwise_BN… │
# │ (ReLU)                    │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project (Conv2D) │ (None, 7, 7, 320)      │        307,200 │ block_16_depthwise_re… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ block_16_project_BN       │ (None, 7, 7, 320)      │          1,280 │ block_16_project[0][0] │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1 (Conv2D)           │ (None, 7, 7, 1280)     │        409,600 │ block_16_project_BN[0… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ Conv_1_bn                 │ (None, 7, 7, 1280)     │          5,120 │ Conv_1[0][0]           │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ out_relu (ReLU)           │ (None, 7, 7, 1280)     │              0 │ Conv_1_bn[0][0]        │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 2,257,984 (8.61 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 2,257,984 (8.61 MB)

# %% [markdown]
# # **Compute Class Weights For Balanced Training :**
# **N.B. Since we already blance our dataset we don't need to use class weights for balance the training.**

# %%
train_labels = train_gen.classes
class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(train_labels), y=train_labels)
class_weights_dict = dict(enumerate(class_weights))
print(f"Class weights: [{class_weights_dict}]")
# Out:
# Class weights: [{0: 1.0012210012210012, 1: 1.0049019607843137, 2: 1.0012210012210012, 3: 0.9975669099756691, 4: 0.9975669099756691, 5: 0.9975669099756691}]

# %% [markdown]
# # **Transfer Learning With Frozen Base :**

# %%
def train_with_frozen_base(train_gen, val_gen, new_model, checkpoint_model_save_path, base_initial_lr, epochs_frozen, #class_weights
                           ):
    
    # Compile model for initial training 
    new_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_initial_lr),
                      loss='categorical_crossentropy',
                      metrics=['accuracy',
                               tf.keras.metrics.TopKCategoricalAccuracy(k=2, name='top_2_accuracy'),
                               tf.keras.metrics.Precision(name='precision'),
                                tf.keras.metrics.Recall(name='recall')])
    
    # Define callbacks
    callbacks = [EarlyStopping(monitor='val_loss', patience=300, restore_best_weights=True, verbose=1),
                 ModelCheckpoint(checkpoint_model_save_path, monitor='val_loss', save_best_only=True, verbose=1),
                 ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0000001, verbose=1)]
    
    print("\n" + "="*60)
    print("Phase-01: Training with frozen base...........")
    print(f"Initial Learning Rate: [{base_initial_lr}]")
    print(f"Epochs: [{epochs_frozen}]")
    print(f"Total Layers: [{len(new_model.layers)}]")
    print(f"Trainable Parameters: [{new_model.count_params()}]")
    # Count frozen vs trainable layers
    frozen_layers = sum(1 for layer in new_model.layers if not layer.trainable)
    trainable_layers = sum(1 for layer in new_model.layers if layer.trainable) 
    print(f"Frozen Layers: [{frozen_layers}], Trainable Layers: [{trainable_layers}]")
    print("="*60)
     
    # Fit the new model 
    try:
        history_frozen = new_model.fit(train_gen, validation_data=val_gen, epochs=epochs_frozen, callbacks=callbacks, # class_weight=class_weights
                                       verbose=1)
        print(f"\nPHASE-01: Training Completed Successfully!!!!\n")
    except Exception as e:
        print(f"\nWarning: PHASE-01: Training Failed With Error: {e}")
        print("Please Check Your Data Generators, Model Architecture And Parameters.")
        return None

    # For train summary
    print("="*60)
    print(f"Final Train Loss: [{history_frozen.history['loss'][-1]}]")
    print(f"Best Train Loss: [{min(history_frozen.history['loss'])}]")
    print(f"Final Train Accuracy: [{history_frozen.history['accuracy'][-1]}]")
    print(f"Best Train Accuracy: [{max(history_frozen.history['accuracy'])}]")
    print("="*60)
    
    # For validation summary
    print(f"Final Validation Loss: [{history_frozen.history['val_loss'][-1]}]")
    print(f"Best Validation Loss: [{min(history_frozen.history['val_loss'])}]")
    print(f"Final Validation Accuracy: [{history_frozen.history['val_accuracy'][-1]}]")
    print(f"Best Validation Accuracy: [{max(history_frozen.history['val_accuracy'])}]")
    print("="*60 + "\n")
    
    return history_frozen

# %%
history_frozen = train_with_frozen_base(train_gen=train_gen,
                       val_gen=val_gen, 
                       new_model=new_model,
                       checkpoint_model_save_path="/kaggle/working/ModelCheckpoints/frozen_base.h5",
                       base_initial_lr=0.001,
                       epochs_frozen=300,
                       #class_weights=class_weights_dict
                       )
# Out:
# ============================================================
# Phase-01: Training with frozen base...........
# Initial Learning Rate: [0.001]
# Epochs: [300]
# Total Layers: [165]
# Trainable Parameters: [4264646]
# Frozen Layers: [154], Trainable Layers: [11]
# ============================================================
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750083838.710931     120 service.cc:148] XLA service 0x7e3c20213730 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1750083838.711743     120 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1750083838.711762     120 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1750083839.845378     120 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  1/52 ━━━━━━━━━━━━━━━━━━━━ 15:30 18s/step - accuracy: 0.1250 - loss: 2.4702 - precision: 0.0000e+00 - recall: 0.0000e+00 - top_2_accuracy: 0.2812
# I0000 00:00:1750083846.305613     120 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 731ms/step - accuracy: 0.3430 - loss: 1.7325 - precision: 0.4497 - recall: 0.1897 - top_2_accuracy: 0.5325
# Epoch 1: val_loss improved from inf to 0.76706, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 69s 990ms/step - accuracy: 0.3455 - loss: 1.7265 - precision: 0.4529 - recall: 0.1925 - top_2_accuracy: 0.5351 - val_accuracy: 0.7710 - val_loss: 0.7671 - val_precision: 0.9386 - val_recall: 0.5177 - val_top_2_accuracy: 0.9113 - learning_rate: 0.0010
# Epoch 2/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.6997 - loss: 0.8317 - precision: 0.7789 - recall: 0.6082 - top_2_accuracy: 0.8613
# Epoch 2: val_loss improved from 0.76706 to 0.54400, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 452ms/step - accuracy: 0.6999 - loss: 0.8313 - precision: 0.7791 - recall: 0.6088 - top_2_accuracy: 0.8614 - val_accuracy: 0.8161 - val_loss: 0.5440 - val_precision: 0.8846 - val_recall: 0.7419 - val_top_2_accuracy: 0.9500 - learning_rate: 0.0010
# Epoch 3/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.7844 - loss: 0.6779 - precision: 0.8207 - recall: 0.7177 - top_2_accuracy: 0.9122
# Epoch 3: val_loss improved from 0.54400 to 0.30716, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 464ms/step - accuracy: 0.7845 - loss: 0.6772 - precision: 0.8208 - recall: 0.7180 - top_2_accuracy: 0.9123 - val_accuracy: 0.8887 - val_loss: 0.3072 - val_precision: 0.9278 - val_recall: 0.8500 - val_top_2_accuracy: 0.9758 - learning_rate: 0.0010
# Epoch 4/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.7957 - loss: 0.6311 - precision: 0.8453 - recall: 0.7556 - top_2_accuracy: 0.9083
# Epoch 4: val_loss improved from 0.30716 to 0.24872, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 462ms/step - accuracy: 0.7959 - loss: 0.6301 - precision: 0.8454 - recall: 0.7557 - top_2_accuracy: 0.9086 - val_accuracy: 0.9258 - val_loss: 0.2487 - val_precision: 0.9485 - val_recall: 0.8903 - val_top_2_accuracy: 0.9726 - learning_rate: 0.0010
# Epoch 5/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step - accuracy: 0.8302 - loss: 0.4768 - precision: 0.8598 - recall: 0.7998 - top_2_accuracy: 0.9586
# Epoch 5: val_loss did not improve from 0.24872
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 25s 485ms/step - accuracy: 0.8303 - loss: 0.4768 - precision: 0.8599 - recall: 0.7999 - top_2_accuracy: 0.9586 - val_accuracy: 0.9016 - val_loss: 0.2544 - val_precision: 0.9271 - val_recall: 0.8823 - val_top_2_accuracy: 0.9823 - learning_rate: 0.0010
# Epoch 6/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.8466 - loss: 0.4525 - precision: 0.8780 - recall: 0.8085 - top_2_accuracy: 0.9594
# Epoch 6: val_loss improved from 0.24872 to 0.19455, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 459ms/step - accuracy: 0.8466 - loss: 0.4524 - precision: 0.8780 - recall: 0.8087 - top_2_accuracy: 0.9594 - val_accuracy: 0.9306 - val_loss: 0.1946 - val_precision: 0.9573 - val_recall: 0.9048 - val_top_2_accuracy: 0.9903 - learning_rate: 0.0010
# Epoch 7/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.8705 - loss: 0.3639 - precision: 0.8974 - recall: 0.8458 - top_2_accuracy: 0.9576
# Epoch 7: val_loss improved from 0.19455 to 0.16976, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 463ms/step - accuracy: 0.8704 - loss: 0.3644 - precision: 0.8974 - recall: 0.8457 - top_2_accuracy: 0.9576 - val_accuracy: 0.9419 - val_loss: 0.1698 - val_precision: 0.9505 - val_recall: 0.9290 - val_top_2_accuracy: 0.9919 - learning_rate: 0.0010
# Epoch 8/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.8754 - loss: 0.3653 - precision: 0.8882 - recall: 0.8521 - top_2_accuracy: 0.9657
# Epoch 8: val_loss improved from 0.16976 to 0.14793, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 457ms/step - accuracy: 0.8753 - loss: 0.3654 - precision: 0.8884 - recall: 0.8521 - top_2_accuracy: 0.9657 - val_accuracy: 0.9371 - val_loss: 0.1479 - val_precision: 0.9534 - val_recall: 0.9242 - val_top_2_accuracy: 0.9952 - learning_rate: 0.0010
# Epoch 9/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.8975 - loss: 0.3289 - precision: 0.9156 - recall: 0.8684 - top_2_accuracy: 0.9725
# Epoch 9: val_loss did not improve from 0.14793
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 450ms/step - accuracy: 0.8973 - loss: 0.3293 - precision: 0.9155 - recall: 0.8682 - top_2_accuracy: 0.9725 - val_accuracy: 0.9419 - val_loss: 0.1613 - val_precision: 0.9472 - val_recall: 0.9258 - val_top_2_accuracy: 0.9968 - learning_rate: 0.0010
# Epoch 10/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.8988 - loss: 0.3239 - precision: 0.9115 - recall: 0.8787 - top_2_accuracy: 0.9728
# Epoch 10: val_loss did not improve from 0.14793
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 455ms/step - accuracy: 0.8988 - loss: 0.3237 - precision: 0.9115 - recall: 0.8787 - top_2_accuracy: 0.9728 - val_accuracy: 0.9435 - val_loss: 0.1653 - val_precision: 0.9535 - val_recall: 0.9258 - val_top_2_accuracy: 0.9919 - learning_rate: 0.0010
# Epoch 11/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.9070 - loss: 0.2736 - precision: 0.9254 - recall: 0.8921 - top_2_accuracy: 0.9785
# Epoch 11: val_loss improved from 0.14793 to 0.13440, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 459ms/step - accuracy: 0.9069 - loss: 0.2743 - precision: 0.9253 - recall: 0.8920 - top_2_accuracy: 0.9785 - val_accuracy: 0.9452 - val_loss: 0.1344 - val_precision: 0.9539 - val_recall: 0.9339 - val_top_2_accuracy: 0.9968 - learning_rate: 0.0010
# Epoch 12/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.9088 - loss: 0.3084 - precision: 0.9259 - recall: 0.8853 - top_2_accuracy: 0.9741
# Epoch 12: val_loss improved from 0.13440 to 0.13255, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 454ms/step - accuracy: 0.9086 - loss: 0.3090 - precision: 0.9258 - recall: 0.8850 - top_2_accuracy: 0.9739 - val_accuracy: 0.9548 - val_loss: 0.1326 - val_precision: 0.9575 - val_recall: 0.9452 - val_top_2_accuracy: 0.9968 - learning_rate: 0.0010
# Epoch 13/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.9045 - loss: 0.2762 - precision: 0.9322 - recall: 0.8800 - top_2_accuracy: 0.9799
# Epoch 13: val_loss improved from 0.13255 to 0.13079, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 460ms/step - accuracy: 0.9043 - loss: 0.2766 - precision: 0.9320 - recall: 0.8798 - top_2_accuracy: 0.9798 - val_accuracy: 0.9548 - val_loss: 0.1308 - val_precision: 0.9719 - val_recall: 0.9484 - val_top_2_accuracy: 0.9952 - learning_rate: 0.0010
# Epoch 14/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.9054 - loss: 0.2713 - precision: 0.9191 - recall: 0.8876 - top_2_accuracy: 0.9810
# Epoch 14: val_loss improved from 0.13079 to 0.10782, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 455ms/step - accuracy: 0.9054 - loss: 0.2716 - precision: 0.9190 - recall: 0.8876 - top_2_accuracy: 0.9810 - val_accuracy: 0.9613 - val_loss: 0.1078 - val_precision: 0.9753 - val_recall: 0.9565 - val_top_2_accuracy: 0.9968 - learning_rate: 0.0010
# Epoch 15/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9163 - loss: 0.2496 - precision: 0.9297 - recall: 0.9069 - top_2_accuracy: 0.9803
# Epoch 15: val_loss did not improve from 0.10782
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 454ms/step - accuracy: 0.9161 - loss: 0.2502 - precision: 0.9297 - recall: 0.9067 - top_2_accuracy: 0.9802 - val_accuracy: 0.9532 - val_loss: 0.1177 - val_precision: 0.9624 - val_recall: 0.9484 - val_top_2_accuracy: 0.9968 - learning_rate: 0.0010
# Epoch 16/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.9161 - loss: 0.2795 - precision: 0.9282 - recall: 0.9084 - top_2_accuracy: 0.9762
# Epoch 16: val_loss improved from 0.10782 to 0.10688, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 455ms/step - accuracy: 0.9160 - loss: 0.2797 - precision: 0.9282 - recall: 0.9083 - top_2_accuracy: 0.9762 - val_accuracy: 0.9516 - val_loss: 0.1069 - val_precision: 0.9557 - val_recall: 0.9403 - val_top_2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 17/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.9192 - loss: 0.2291 - precision: 0.9287 - recall: 0.9071 - top_2_accuracy: 0.9801
# Epoch 17: val_loss improved from 0.10688 to 0.07264, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 457ms/step - accuracy: 0.9192 - loss: 0.2291 - precision: 0.9287 - recall: 0.9072 - top_2_accuracy: 0.9802 - val_accuracy: 0.9694 - val_loss: 0.0726 - val_precision: 0.9756 - val_recall: 0.9694 - val_top_2_accuracy: 0.9984 - learning_rate: 0.0010
# Epoch 18/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.9268 - loss: 0.2384 - precision: 0.9426 - recall: 0.9148 - top_2_accuracy: 0.9858
# Epoch 18: val_loss did not improve from 0.07264
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 457ms/step - accuracy: 0.9268 - loss: 0.2385 - precision: 0.9426 - recall: 0.9148 - top_2_accuracy: 0.9858 - val_accuracy: 0.9742 - val_loss: 0.0803 - val_precision: 0.9788 - val_recall: 0.9694 - val_top_2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 19/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.9337 - loss: 0.2134 - precision: 0.9423 - recall: 0.9181 - top_2_accuracy: 0.9884
# Epoch 19: val_loss improved from 0.07264 to 0.06607, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 456ms/step - accuracy: 0.9337 - loss: 0.2140 - precision: 0.9423 - recall: 0.9181 - top_2_accuracy: 0.9883 - val_accuracy: 0.9823 - val_loss: 0.0661 - val_precision: 0.9853 - val_recall: 0.9758 - val_top_2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 20/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step - accuracy: 0.9128 - loss: 0.2403 - precision: 0.9314 - recall: 0.8976 - top_2_accuracy: 0.9727
# Epoch 20: val_loss did not improve from 0.06607
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 27s 512ms/step - accuracy: 0.9129 - loss: 0.2401 - precision: 0.9314 - recall: 0.8977 - top_2_accuracy: 0.9728 - val_accuracy: 0.9806 - val_loss: 0.0675 - val_precision: 0.9853 - val_recall: 0.9742 - val_top_2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 21/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.9300 - loss: 0.2153 - precision: 0.9425 - recall: 0.9241 - top_2_accuracy: 0.9887
# Epoch 21: val_loss improved from 0.06607 to 0.04231, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 453ms/step - accuracy: 0.9302 - loss: 0.2151 - precision: 0.9426 - recall: 0.9241 - top_2_accuracy: 0.9887 - val_accuracy: 0.9855 - val_loss: 0.0423 - val_precision: 0.9854 - val_recall: 0.9790 - val_top_2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 22/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.9259 - loss: 0.2477 - precision: 0.9359 - recall: 0.9197 - top_2_accuracy: 0.9853
# Epoch 22: val_loss did not improve from 0.04231
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 440ms/step - accuracy: 0.9259 - loss: 0.2476 - precision: 0.9360 - recall: 0.9195 - top_2_accuracy: 0.9853 - val_accuracy: 0.9452 - val_loss: 0.1368 - val_precision: 0.9511 - val_recall: 0.9419 - val_top_2_accuracy: 0.9887 - learning_rate: 0.0010
# Epoch 23/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.9347 - loss: 0.2234 - precision: 0.9471 - recall: 0.9202 - top_2_accuracy: 0.9774
# Epoch 23: val_loss did not improve from 0.04231
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 447ms/step - accuracy: 0.9348 - loss: 0.2231 - precision: 0.9472 - recall: 0.9202 - top_2_accuracy: 0.9774 - val_accuracy: 0.9710 - val_loss: 0.0767 - val_precision: 0.9756 - val_recall: 0.9694 - val_top_2_accuracy: 0.9984 - learning_rate: 0.0010
# Epoch 24/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.9275 - loss: 0.2316 - precision: 0.9362 - recall: 0.9148 - top_2_accuracy: 0.9878
# Epoch 24: val_loss did not improve from 0.04231
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 446ms/step - accuracy: 0.9276 - loss: 0.2313 - precision: 0.9363 - recall: 0.9149 - top_2_accuracy: 0.9878 - val_accuracy: 0.9774 - val_loss: 0.0596 - val_precision: 0.9790 - val_recall: 0.9758 - val_top_2_accuracy: 0.9984 - learning_rate: 0.0010
# Epoch 25/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.9397 - loss: 0.2058 - precision: 0.9462 - recall: 0.9250 - top_2_accuracy: 0.9817
# Epoch 25: val_loss did not improve from 0.04231
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 441ms/step - accuracy: 0.9395 - loss: 0.2066 - precision: 0.9460 - recall: 0.9248 - top_2_accuracy: 0.9817 - val_accuracy: 0.9790 - val_loss: 0.0624 - val_precision: 0.9821 - val_recall: 0.9758 - val_top_2_accuracy: 1.0000 - learning_rate: 0.0010
# Epoch 26/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.9527 - loss: 0.1446 - precision: 0.9643 - recall: 0.9386 - top_2_accuracy: 0.9903
# Epoch 26: val_loss did not improve from 0.04231
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 438ms/step - accuracy: 0.9525 - loss: 0.1451 - precision: 0.9641 - recall: 0.9385 - top_2_accuracy: 0.9903 - val_accuracy: 0.9613 - val_loss: 0.1177 - val_precision: 0.9659 - val_recall: 0.9597 - val_top_2_accuracy: 0.9952 - learning_rate: 0.0010
# Epoch 27/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.9359 - loss: 0.2144 - precision: 0.9427 - recall: 0.9288 - top_2_accuracy: 0.9866
# Epoch 27: val_loss did not improve from 0.04231
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 454ms/step - accuracy: 0.9359 - loss: 0.2144 - precision: 0.9426 - recall: 0.9287 - top_2_accuracy: 0.9866 - val_accuracy: 0.9742 - val_loss: 0.0629 - val_precision: 0.9742 - val_recall: 0.9726 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 28/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 544ms/step - accuracy: 0.9562 - loss: 0.1865 - precision: 0.9623 - recall: 0.9437 - top_2_accuracy: 0.9913
# Epoch 28: val_loss did not improve from 0.04231
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 31s 605ms/step - accuracy: 0.9562 - loss: 0.1858 - precision: 0.9623 - recall: 0.9438 - top_2_accuracy: 0.9912 - val_accuracy: 0.9774 - val_loss: 0.0558 - val_precision: 0.9790 - val_recall: 0.9774 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 29/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 550ms/step - accuracy: 0.9465 - loss: 0.1630 - precision: 0.9497 - recall: 0.9379 - top_2_accuracy: 0.9907
# Epoch 29: val_loss did not improve from 0.04231
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 31s 594ms/step - accuracy: 0.9467 - loss: 0.1627 - precision: 0.9499 - recall: 0.9381 - top_2_accuracy: 0.9908 - val_accuracy: 0.9774 - val_loss: 0.0507 - val_precision: 0.9790 - val_recall: 0.9774 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 30/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 542ms/step - accuracy: 0.9565 - loss: 0.1321 - precision: 0.9611 - recall: 0.9403 - top_2_accuracy: 0.9964
# Epoch 30: val_loss improved from 0.04231 to 0.03754, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 32s 610ms/step - accuracy: 0.9564 - loss: 0.1322 - precision: 0.9611 - recall: 0.9404 - top_2_accuracy: 0.9964 - val_accuracy: 0.9774 - val_loss: 0.0375 - val_precision: 0.9790 - val_recall: 0.9774 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 31/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 534ms/step - accuracy: 0.9485 - loss: 0.1608 - precision: 0.9541 - recall: 0.9376 - top_2_accuracy: 0.9898
# Epoch 31: val_loss improved from 0.03754 to 0.03697, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 30s 571ms/step - accuracy: 0.9486 - loss: 0.1608 - precision: 0.9542 - recall: 0.9377 - top_2_accuracy: 0.9899 - val_accuracy: 0.9839 - val_loss: 0.0370 - val_precision: 0.9854 - val_recall: 0.9823 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 32/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.9635 - loss: 0.1489 - precision: 0.9678 - recall: 0.9541 - top_2_accuracy: 0.9907
# Epoch 32: val_loss did not improve from 0.03697
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 441ms/step - accuracy: 0.9635 - loss: 0.1488 - precision: 0.9678 - recall: 0.9540 - top_2_accuracy: 0.9907 - val_accuracy: 0.9823 - val_loss: 0.0430 - val_precision: 0.9838 - val_recall: 0.9823 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 33/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.9638 - loss: 0.1264 - precision: 0.9694 - recall: 0.9580 - top_2_accuracy: 0.9835
# Epoch 33: val_loss did not improve from 0.03697
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 446ms/step - accuracy: 0.9638 - loss: 0.1264 - precision: 0.9694 - recall: 0.9580 - top_2_accuracy: 0.9836 - val_accuracy: 0.9855 - val_loss: 0.0403 - val_precision: 0.9871 - val_recall: 0.9855 - val_top_2_accuracy: 0.9968 - learning_rate: 2.0000e-04
# Epoch 34/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.9569 - loss: 0.1214 - precision: 0.9626 - recall: 0.9518 - top_2_accuracy: 0.9937
# Epoch 34: val_loss improved from 0.03697 to 0.03668, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 462ms/step - accuracy: 0.9570 - loss: 0.1215 - precision: 0.9626 - recall: 0.9518 - top_2_accuracy: 0.9937 - val_accuracy: 0.9855 - val_loss: 0.0367 - val_precision: 0.9871 - val_recall: 0.9839 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 35/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.9573 - loss: 0.1298 - precision: 0.9642 - recall: 0.9508 - top_2_accuracy: 0.9911
# Epoch 35: val_loss improved from 0.03668 to 0.03249, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 451ms/step - accuracy: 0.9573 - loss: 0.1298 - precision: 0.9643 - recall: 0.9508 - top_2_accuracy: 0.9911 - val_accuracy: 0.9871 - val_loss: 0.0325 - val_precision: 0.9871 - val_recall: 0.9855 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 36/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.9726 - loss: 0.0878 - precision: 0.9753 - recall: 0.9629 - top_2_accuracy: 0.9997
# Epoch 36: val_loss improved from 0.03249 to 0.02787, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 457ms/step - accuracy: 0.9725 - loss: 0.0883 - precision: 0.9751 - recall: 0.9627 - top_2_accuracy: 0.9996 - val_accuracy: 0.9887 - val_loss: 0.0279 - val_precision: 0.9903 - val_recall: 0.9887 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 37/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.9629 - loss: 0.1259 - precision: 0.9712 - recall: 0.9588 - top_2_accuracy: 0.9972
# Epoch 37: val_loss did not improve from 0.02787
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 454ms/step - accuracy: 0.9630 - loss: 0.1256 - precision: 0.9713 - recall: 0.9589 - top_2_accuracy: 0.9972 - val_accuracy: 0.9903 - val_loss: 0.0279 - val_precision: 0.9935 - val_recall: 0.9903 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 38/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.9595 - loss: 0.1376 - precision: 0.9615 - recall: 0.9535 - top_2_accuracy: 0.9930
# Epoch 38: val_loss did not improve from 0.02787
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 442ms/step - accuracy: 0.9594 - loss: 0.1378 - precision: 0.9615 - recall: 0.9534 - top_2_accuracy: 0.9929 - val_accuracy: 0.9903 - val_loss: 0.0296 - val_precision: 0.9919 - val_recall: 0.9903 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 39/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.9697 - loss: 0.0902 - precision: 0.9734 - recall: 0.9675 - top_2_accuracy: 0.9958
# Epoch 39: val_loss improved from 0.02787 to 0.02659, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 452ms/step - accuracy: 0.9697 - loss: 0.0904 - precision: 0.9733 - recall: 0.9674 - top_2_accuracy: 0.9958 - val_accuracy: 0.9903 - val_loss: 0.0266 - val_precision: 0.9919 - val_recall: 0.9903 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 40/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.9647 - loss: 0.1061 - precision: 0.9695 - recall: 0.9606 - top_2_accuracy: 0.9973
# Epoch 40: val_loss improved from 0.02659 to 0.02429, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 446ms/step - accuracy: 0.9646 - loss: 0.1064 - precision: 0.9694 - recall: 0.9606 - top_2_accuracy: 0.9973 - val_accuracy: 0.9919 - val_loss: 0.0243 - val_precision: 0.9935 - val_recall: 0.9919 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 41/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.9612 - loss: 0.1208 - precision: 0.9672 - recall: 0.9561 - top_2_accuracy: 0.9936
# Epoch 41: val_loss did not improve from 0.02429
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 434ms/step - accuracy: 0.9612 - loss: 0.1208 - precision: 0.9671 - recall: 0.9560 - top_2_accuracy: 0.9936 - val_accuracy: 0.9903 - val_loss: 0.0251 - val_precision: 0.9919 - val_recall: 0.9903 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 42/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.9611 - loss: 0.1301 - precision: 0.9687 - recall: 0.9553 - top_2_accuracy: 0.9964
# Epoch 42: val_loss did not improve from 0.02429
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 438ms/step - accuracy: 0.9612 - loss: 0.1296 - precision: 0.9688 - recall: 0.9554 - top_2_accuracy: 0.9964 - val_accuracy: 0.9919 - val_loss: 0.0253 - val_precision: 0.9951 - val_recall: 0.9903 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 43/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.9652 - loss: 0.1194 - precision: 0.9699 - recall: 0.9599 - top_2_accuracy: 0.9919
# Epoch 43: val_loss improved from 0.02429 to 0.02305, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 443ms/step - accuracy: 0.9652 - loss: 0.1193 - precision: 0.9699 - recall: 0.9599 - top_2_accuracy: 0.9919 - val_accuracy: 0.9871 - val_loss: 0.0231 - val_precision: 0.9903 - val_recall: 0.9871 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 44/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9654 - loss: 0.1186 - precision: 0.9713 - recall: 0.9608 - top_2_accuracy: 0.9940
# Epoch 44: val_loss did not improve from 0.02305
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 424ms/step - accuracy: 0.9655 - loss: 0.1183 - precision: 0.9714 - recall: 0.9609 - top_2_accuracy: 0.9940 - val_accuracy: 0.9935 - val_loss: 0.0241 - val_precision: 0.9951 - val_recall: 0.9887 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 45/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9605 - loss: 0.1038 - precision: 0.9667 - recall: 0.9539 - top_2_accuracy: 0.9964
# Epoch 45: val_loss improved from 0.02305 to 0.02227, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 431ms/step - accuracy: 0.9607 - loss: 0.1037 - precision: 0.9667 - recall: 0.9540 - top_2_accuracy: 0.9964 - val_accuracy: 0.9935 - val_loss: 0.0223 - val_precision: 0.9935 - val_recall: 0.9919 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 46/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step - accuracy: 0.9777 - loss: 0.0804 - precision: 0.9798 - recall: 0.9721 - top_2_accuracy: 0.9948
# Epoch 46: val_loss did not improve from 0.02227
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 418ms/step - accuracy: 0.9777 - loss: 0.0805 - precision: 0.9798 - recall: 0.9721 - top_2_accuracy: 0.9948 - val_accuracy: 0.9903 - val_loss: 0.0264 - val_precision: 0.9903 - val_recall: 0.9903 - val_top_2_accuracy: 0.9984 - learning_rate: 2.0000e-04
# Epoch 47/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.9680 - loss: 0.1035 - precision: 0.9726 - recall: 0.9637 - top_2_accuracy: 0.9944
# Epoch 47: val_loss did not improve from 0.02227
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 433ms/step - accuracy: 0.9679 - loss: 0.1036 - precision: 0.9725 - recall: 0.9636 - top_2_accuracy: 0.9945 - val_accuracy: 0.9903 - val_loss: 0.0281 - val_precision: 0.9919 - val_recall: 0.9903 - val_top_2_accuracy: 0.9984 - learning_rate: 2.0000e-04
# Epoch 48/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step - accuracy: 0.9727 - loss: 0.0754 - precision: 0.9741 - recall: 0.9710 - top_2_accuracy: 0.9992
# Epoch 48: val_loss did not improve from 0.02227
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 26s 494ms/step - accuracy: 0.9725 - loss: 0.0756 - precision: 0.9740 - recall: 0.9709 - top_2_accuracy: 0.9992 - val_accuracy: 0.9919 - val_loss: 0.0250 - val_precision: 0.9919 - val_recall: 0.9919 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 49/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.9673 - loss: 0.0954 - precision: 0.9686 - recall: 0.9641 - top_2_accuracy: 0.9969
# Epoch 49: val_loss did not improve from 0.02227
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 463ms/step - accuracy: 0.9673 - loss: 0.0952 - precision: 0.9686 - recall: 0.9642 - top_2_accuracy: 0.9969 - val_accuracy: 0.9935 - val_loss: 0.0283 - val_precision: 0.9935 - val_recall: 0.9919 - val_top_2_accuracy: 0.9984 - learning_rate: 2.0000e-04
# Epoch 50/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9647 - loss: 0.0875 - precision: 0.9687 - recall: 0.9625 - top_2_accuracy: 0.9976
# Epoch 50: val_loss did not improve from 0.02227
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 427ms/step - accuracy: 0.9648 - loss: 0.0875 - precision: 0.9688 - recall: 0.9625 - top_2_accuracy: 0.9976 - val_accuracy: 0.9903 - val_loss: 0.0271 - val_precision: 0.9919 - val_recall: 0.9903 - val_top_2_accuracy: 1.0000 - learning_rate: 2.0000e-04
# Epoch 51/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9713 - loss: 0.1040 - precision: 0.9744 - recall: 0.9690 - top_2_accuracy: 0.9966
# Epoch 51: val_loss did not improve from 0.02227
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 433ms/step - accuracy: 0.9713 - loss: 0.1037 - precision: 0.9745 - recall: 0.9690 - top_2_accuracy: 0.9965 - val_accuracy: 0.9919 - val_loss: 0.0240 - val_precision: 0.9919 - val_recall: 0.9919 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 52/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9688 - loss: 0.1010 - precision: 0.9758 - recall: 0.9655 - top_2_accuracy: 0.9938
# Epoch 52: val_loss improved from 0.02227 to 0.02216, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 430ms/step - accuracy: 0.9689 - loss: 0.1009 - precision: 0.9759 - recall: 0.9656 - top_2_accuracy: 0.9938 - val_accuracy: 0.9935 - val_loss: 0.0222 - val_precision: 0.9935 - val_recall: 0.9935 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 53/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.9690 - loss: 0.0956 - precision: 0.9723 - recall: 0.9632 - top_2_accuracy: 0.9962
# Epoch 53: val_loss improved from 0.02216 to 0.02199, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 442ms/step - accuracy: 0.9690 - loss: 0.0953 - precision: 0.9724 - recall: 0.9632 - top_2_accuracy: 0.9962 - val_accuracy: 0.9952 - val_loss: 0.0220 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 54/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step - accuracy: 0.9690 - loss: 0.1058 - precision: 0.9744 - recall: 0.9622 - top_2_accuracy: 0.9947
# Epoch 54: val_loss did not improve from 0.02199
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 417ms/step - accuracy: 0.9690 - loss: 0.1055 - precision: 0.9744 - recall: 0.9622 - top_2_accuracy: 0.9947 - val_accuracy: 0.9935 - val_loss: 0.0225 - val_precision: 0.9935 - val_recall: 0.9935 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 55/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9685 - loss: 0.1036 - precision: 0.9694 - recall: 0.9655 - top_2_accuracy: 0.9981
# Epoch 55: val_loss did not improve from 0.02199
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 424ms/step - accuracy: 0.9685 - loss: 0.1035 - precision: 0.9694 - recall: 0.9655 - top_2_accuracy: 0.9980 - val_accuracy: 0.9935 - val_loss: 0.0224 - val_precision: 0.9935 - val_recall: 0.9935 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 56/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step - accuracy: 0.9755 - loss: 0.0919 - precision: 0.9824 - recall: 0.9712 - top_2_accuracy: 0.9948
# Epoch 56: val_loss improved from 0.02199 to 0.02189, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 427ms/step - accuracy: 0.9755 - loss: 0.0919 - precision: 0.9823 - recall: 0.9711 - top_2_accuracy: 0.9948 - val_accuracy: 0.9919 - val_loss: 0.0219 - val_precision: 0.9919 - val_recall: 0.9919 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 57/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 396ms/step - accuracy: 0.9710 - loss: 0.0842 - precision: 0.9733 - recall: 0.9671 - top_2_accuracy: 0.9936
# Epoch 57: val_loss improved from 0.02189 to 0.02039, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 433ms/step - accuracy: 0.9710 - loss: 0.0842 - precision: 0.9733 - recall: 0.9671 - top_2_accuracy: 0.9936 - val_accuracy: 0.9952 - val_loss: 0.0204 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 58/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.9787 - loss: 0.0753 - precision: 0.9848 - recall: 0.9765 - top_2_accuracy: 0.9961
# Epoch 58: val_loss improved from 0.02039 to 0.02022, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 429ms/step - accuracy: 0.9787 - loss: 0.0753 - precision: 0.9847 - recall: 0.9764 - top_2_accuracy: 0.9961 - val_accuracy: 0.9952 - val_loss: 0.0202 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 59/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.9669 - loss: 0.1018 - precision: 0.9719 - recall: 0.9654 - top_2_accuracy: 0.9913
# Epoch 59: val_loss improved from 0.02022 to 0.01945, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 424ms/step - accuracy: 0.9669 - loss: 0.1015 - precision: 0.9719 - recall: 0.9655 - top_2_accuracy: 0.9914 - val_accuracy: 0.9935 - val_loss: 0.0194 - val_precision: 0.9935 - val_recall: 0.9935 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 60/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9734 - loss: 0.0851 - precision: 0.9758 - recall: 0.9674 - top_2_accuracy: 0.9991
# Epoch 60: val_loss improved from 0.01945 to 0.01894, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 435ms/step - accuracy: 0.9734 - loss: 0.0851 - precision: 0.9759 - recall: 0.9674 - top_2_accuracy: 0.9991 - val_accuracy: 0.9952 - val_loss: 0.0189 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 61/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.9756 - loss: 0.0882 - precision: 0.9773 - recall: 0.9694 - top_2_accuracy: 0.9949
# Epoch 61: val_loss improved from 0.01894 to 0.01678, saving model to /kaggle/working/ModelCheckpoints/frozen_base.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 438ms/step - accuracy: 0.9755 - loss: 0.0882 - precision: 0.9773 - recall: 0.9694 - top_2_accuracy: 0.9949 - val_accuracy: 0.9968 - val_loss: 0.0168 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 62/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9779 - loss: 0.0732 - precision: 0.9793 - recall: 0.9754 - top_2_accuracy: 0.9946
# Epoch 62: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 426ms/step - accuracy: 0.9779 - loss: 0.0733 - precision: 0.9793 - recall: 0.9753 - top_2_accuracy: 0.9946 - val_accuracy: 0.9968 - val_loss: 0.0175 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 63/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.9780 - loss: 0.0828 - precision: 0.9800 - recall: 0.9757 - top_2_accuracy: 0.9981
# Epoch 63: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 434ms/step - accuracy: 0.9780 - loss: 0.0828 - precision: 0.9800 - recall: 0.9757 - top_2_accuracy: 0.9981 - val_accuracy: 0.9968 - val_loss: 0.0169 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 64/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.9688 - loss: 0.0957 - precision: 0.9732 - recall: 0.9655 - top_2_accuracy: 0.9959
# Epoch 64: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 435ms/step - accuracy: 0.9689 - loss: 0.0955 - precision: 0.9733 - recall: 0.9656 - top_2_accuracy: 0.9959 - val_accuracy: 0.9968 - val_loss: 0.0172 - val_precision: 0.9968 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 65/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step - accuracy: 0.9710 - loss: 0.0848 - precision: 0.9727 - recall: 0.9652 - top_2_accuracy: 0.9966
# Epoch 65: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 428ms/step - accuracy: 0.9712 - loss: 0.0845 - precision: 0.9728 - recall: 0.9654 - top_2_accuracy: 0.9966 - val_accuracy: 0.9968 - val_loss: 0.0172 - val_precision: 0.9968 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 66/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9617 - loss: 0.0946 - precision: 0.9655 - recall: 0.9566 - top_2_accuracy: 0.9960
# Epoch 66: val_loss did not improve from 0.01678
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 426ms/step - accuracy: 0.9618 - loss: 0.0945 - precision: 0.9656 - recall: 0.9567 - top_2_accuracy: 0.9960 - val_accuracy: 0.9952 - val_loss: 0.0173 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 4.0000e-05
# Epoch 67/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9610 - loss: 0.1195 - precision: 0.9645 - recall: 0.9533 - top_2_accuracy: 0.9925
# Epoch 67: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 431ms/step - accuracy: 0.9612 - loss: 0.1192 - precision: 0.9647 - recall: 0.9535 - top_2_accuracy: 0.9925 - val_accuracy: 0.9952 - val_loss: 0.0173 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 8.0000e-06
# Epoch 68/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.9775 - loss: 0.0703 - precision: 0.9776 - recall: 0.9758 - top_2_accuracy: 0.9983
# Epoch 68: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 426ms/step - accuracy: 0.9775 - loss: 0.0704 - precision: 0.9777 - recall: 0.9758 - top_2_accuracy: 0.9983 - val_accuracy: 0.9968 - val_loss: 0.0170 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 8.0000e-06
# Epoch 69/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 398ms/step - accuracy: 0.9817 - loss: 0.0541 - precision: 0.9834 - recall: 0.9778 - top_2_accuracy: 0.9989
# Epoch 69: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 426ms/step - accuracy: 0.9817 - loss: 0.0543 - precision: 0.9833 - recall: 0.9777 - top_2_accuracy: 0.9989 - val_accuracy: 0.9968 - val_loss: 0.0171 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 8.0000e-06
# Epoch 70/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.9764 - loss: 0.0693 - precision: 0.9786 - recall: 0.9701 - top_2_accuracy: 0.9961
# Epoch 70: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 430ms/step - accuracy: 0.9764 - loss: 0.0695 - precision: 0.9786 - recall: 0.9701 - top_2_accuracy: 0.9961 - val_accuracy: 0.9952 - val_loss: 0.0175 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 8.0000e-06
# Epoch 71/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.9744 - loss: 0.0814 - precision: 0.9782 - recall: 0.9713 - top_2_accuracy: 0.9959
# Epoch 71: val_loss did not improve from 0.01678
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 439ms/step - accuracy: 0.9745 - loss: 0.0812 - precision: 0.9782 - recall: 0.9714 - top_2_accuracy: 0.9959 - val_accuracy: 0.9952 - val_loss: 0.0175 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 8.0000e-06
# Epoch 72/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step - accuracy: 0.9710 - loss: 0.0794 - precision: 0.9733 - recall: 0.9641 - top_2_accuracy: 0.9960
# Epoch 72: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 25s 473ms/step - accuracy: 0.9710 - loss: 0.0794 - precision: 0.9733 - recall: 0.9642 - top_2_accuracy: 0.9960 - val_accuracy: 0.9952 - val_loss: 0.0177 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.6000e-06
# Epoch 73/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.9687 - loss: 0.0971 - precision: 0.9736 - recall: 0.9641 - top_2_accuracy: 0.9953
# Epoch 73: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 466ms/step - accuracy: 0.9686 - loss: 0.0972 - precision: 0.9735 - recall: 0.9640 - top_2_accuracy: 0.9953 - val_accuracy: 0.9952 - val_loss: 0.0176 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.6000e-06
# Epoch 74/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.9863 - loss: 0.0506 - precision: 0.9879 - recall: 0.9829 - top_2_accuracy: 0.9954
# Epoch 74: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 25s 472ms/step - accuracy: 0.9862 - loss: 0.0507 - precision: 0.9878 - recall: 0.9828 - top_2_accuracy: 0.9954 - val_accuracy: 0.9952 - val_loss: 0.0174 - val_precision: 0.9968 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.6000e-06
# Epoch 75/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.9738 - loss: 0.0716 - precision: 0.9761 - recall: 0.9717 - top_2_accuracy: 0.9975
# Epoch 75: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 25s 472ms/step - accuracy: 0.9739 - loss: 0.0715 - precision: 0.9762 - recall: 0.9717 - top_2_accuracy: 0.9975 - val_accuracy: 0.9968 - val_loss: 0.0172 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.6000e-06
# Epoch 76/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.9790 - loss: 0.0673 - precision: 0.9821 - recall: 0.9712 - top_2_accuracy: 0.9982
# Epoch 76: val_loss did not improve from 0.01678
#
# Epoch 76: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 25s 480ms/step - accuracy: 0.9789 - loss: 0.0675 - precision: 0.9820 - recall: 0.9711 - top_2_accuracy: 0.9982 - val_accuracy: 0.9952 - val_loss: 0.0174 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.6000e-06
# Epoch 77/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step - accuracy: 0.9644 - loss: 0.0972 - precision: 0.9712 - recall: 0.9637 - top_2_accuracy: 0.9949
# Epoch 77: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 465ms/step - accuracy: 0.9645 - loss: 0.0969 - precision: 0.9712 - recall: 0.9638 - top_2_accuracy: 0.9950 - val_accuracy: 0.9952 - val_loss: 0.0172 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 3.2000e-07
# Epoch 78/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.9784 - loss: 0.0836 - precision: 0.9793 - recall: 0.9733 - top_2_accuracy: 0.9987
# Epoch 78: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 426ms/step - accuracy: 0.9783 - loss: 0.0835 - precision: 0.9792 - recall: 0.9732 - top_2_accuracy: 0.9987 - val_accuracy: 0.9952 - val_loss: 0.0171 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 3.2000e-07
# Epoch 79/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step - accuracy: 0.9769 - loss: 0.0674 - precision: 0.9806 - recall: 0.9734 - top_2_accuracy: 0.9976
# Epoch 79: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 25s 482ms/step - accuracy: 0.9769 - loss: 0.0675 - precision: 0.9805 - recall: 0.9733 - top_2_accuracy: 0.9976 - val_accuracy: 0.9968 - val_loss: 0.0170 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 3.2000e-07
# Epoch 80/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.9783 - loss: 0.0757 - precision: 0.9803 - recall: 0.9741 - top_2_accuracy: 0.9967
# Epoch 80: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 442ms/step - accuracy: 0.9782 - loss: 0.0757 - precision: 0.9803 - recall: 0.9741 - top_2_accuracy: 0.9967 - val_accuracy: 0.9952 - val_loss: 0.0172 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 3.2000e-07
# Epoch 81/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step - accuracy: 0.9810 - loss: 0.0603 - precision: 0.9842 - recall: 0.9789 - top_2_accuracy: 0.9979
# Epoch 81: val_loss did not improve from 0.01678
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 1e-07.
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 26s 500ms/step - accuracy: 0.9808 - loss: 0.0606 - precision: 0.9840 - recall: 0.9788 - top_2_accuracy: 0.9978 - val_accuracy: 0.9968 - val_loss: 0.0169 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 3.2000e-07
# Epoch 82/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step - accuracy: 0.9755 - loss: 0.0758 - precision: 0.9780 - recall: 0.9711 - top_2_accuracy: 0.9976
# Epoch 82: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 26s 509ms/step - accuracy: 0.9755 - loss: 0.0756 - precision: 0.9780 - recall: 0.9712 - top_2_accuracy: 0.9976 - val_accuracy: 0.9968 - val_loss: 0.0170 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 83/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 503ms/step - accuracy: 0.9780 - loss: 0.0768 - precision: 0.9806 - recall: 0.9740 - top_2_accuracy: 0.9959
# Epoch 83: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 30s 580ms/step - accuracy: 0.9780 - loss: 0.0767 - precision: 0.9806 - recall: 0.9739 - top_2_accuracy: 0.9959 - val_accuracy: 0.9968 - val_loss: 0.0170 - val_precision: 0.9968 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 84/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step - accuracy: 0.9792 - loss: 0.0631 - precision: 0.9834 - recall: 0.9715 - top_2_accuracy: 0.9951
# Epoch 84: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 27s 513ms/step - accuracy: 0.9793 - loss: 0.0629 - precision: 0.9835 - recall: 0.9716 - top_2_accuracy: 0.9952 - val_accuracy: 0.9968 - val_loss: 0.0172 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 85/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.9770 - loss: 0.0876 - precision: 0.9781 - recall: 0.9710 - top_2_accuracy: 0.9965
# Epoch 85: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 449ms/step - accuracy: 0.9770 - loss: 0.0876 - precision: 0.9781 - recall: 0.9711 - top_2_accuracy: 0.9965 - val_accuracy: 0.9952 - val_loss: 0.0172 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 86/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.9834 - loss: 0.0783 - precision: 0.9840 - recall: 0.9800 - top_2_accuracy: 0.9956
# Epoch 86: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 448ms/step - accuracy: 0.9834 - loss: 0.0781 - precision: 0.9840 - recall: 0.9801 - top_2_accuracy: 0.9957 - val_accuracy: 0.9952 - val_loss: 0.0173 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 87/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.9621 - loss: 0.1414 - precision: 0.9634 - recall: 0.9539 - top_2_accuracy: 0.9927
# Epoch 87: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 426ms/step - accuracy: 0.9622 - loss: 0.1408 - precision: 0.9636 - recall: 0.9541 - top_2_accuracy: 0.9928 - val_accuracy: 0.9952 - val_loss: 0.0173 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 88/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.9723 - loss: 0.0903 - precision: 0.9744 - recall: 0.9704 - top_2_accuracy: 0.9959
# Epoch 88: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 439ms/step - accuracy: 0.9723 - loss: 0.0902 - precision: 0.9744 - recall: 0.9705 - top_2_accuracy: 0.9960 - val_accuracy: 0.9952 - val_loss: 0.0172 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 89/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.9719 - loss: 0.0651 - precision: 0.9835 - recall: 0.9702 - top_2_accuracy: 0.9954
# Epoch 89: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 443ms/step - accuracy: 0.9719 - loss: 0.0651 - precision: 0.9835 - recall: 0.9703 - top_2_accuracy: 0.9954 - val_accuracy: 0.9968 - val_loss: 0.0170 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 90/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 395ms/step - accuracy: 0.9767 - loss: 0.0627 - precision: 0.9812 - recall: 0.9725 - top_2_accuracy: 0.9956
# Epoch 90: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 423ms/step - accuracy: 0.9768 - loss: 0.0626 - precision: 0.9812 - recall: 0.9725 - top_2_accuracy: 0.9956 - val_accuracy: 0.9952 - val_loss: 0.0172 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 91/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.9810 - loss: 0.0604 - precision: 0.9842 - recall: 0.9804 - top_2_accuracy: 0.9992
# Epoch 91: val_loss did not improve from 0.01678
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 429ms/step - accuracy: 0.9809 - loss: 0.0605 - precision: 0.9840 - recall: 0.9803 - top_2_accuracy: 0.9992 - val_accuracy: 0.9968 - val_loss: 0.0172 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 92/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9826 - loss: 0.0638 - precision: 0.9859 - recall: 0.9751 - top_2_accuracy: 0.9981
# Epoch 92: val_loss did not improve from 0.01678
# ...
# Epoch 269: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 435ms/step - accuracy: 0.9709 - loss: 0.0791 - precision: 0.9783 - recall: 0.9662 - top_2_accuracy: 0.9962 - val_accuracy: 0.9968 - val_loss: 0.0169 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 270/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.9759 - loss: 0.0642 - precision: 0.9798 - recall: 0.9742 - top_2_accuracy: 0.9981
# Epoch 270: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 437ms/step - accuracy: 0.9758 - loss: 0.0643 - precision: 0.9797 - recall: 0.9742 - top_2_accuracy: 0.9981 - val_accuracy: 0.9968 - val_loss: 0.0170 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 271/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.9772 - loss: 0.0739 - precision: 0.9793 - recall: 0.9700 - top_2_accuracy: 0.9996
# Epoch 271: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 436ms/step - accuracy: 0.9772 - loss: 0.0740 - precision: 0.9792 - recall: 0.9700 - top_2_accuracy: 0.9996 - val_accuracy: 0.9968 - val_loss: 0.0174 - val_precision: 0.9968 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 272/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.9785 - loss: 0.0731 - precision: 0.9806 - recall: 0.9753 - top_2_accuracy: 0.9977
# Epoch 272: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 436ms/step - accuracy: 0.9784 - loss: 0.0733 - precision: 0.9805 - recall: 0.9752 - top_2_accuracy: 0.9977 - val_accuracy: 0.9968 - val_loss: 0.0172 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 273/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.9802 - loss: 0.0660 - precision: 0.9826 - recall: 0.9794 - top_2_accuracy: 0.9977
# Epoch 273: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 464ms/step - accuracy: 0.9802 - loss: 0.0662 - precision: 0.9826 - recall: 0.9794 - top_2_accuracy: 0.9977 - val_accuracy: 0.9952 - val_loss: 0.0174 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 274/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.9648 - loss: 0.0899 - precision: 0.9739 - recall: 0.9594 - top_2_accuracy: 0.9922
# Epoch 274: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 438ms/step - accuracy: 0.9649 - loss: 0.0898 - precision: 0.9739 - recall: 0.9595 - top_2_accuracy: 0.9923 - val_accuracy: 0.9968 - val_loss: 0.0173 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 275/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.9796 - loss: 0.0647 - precision: 0.9836 - recall: 0.9777 - top_2_accuracy: 0.9983
# Epoch 275: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 440ms/step - accuracy: 0.9795 - loss: 0.0649 - precision: 0.9836 - recall: 0.9776 - top_2_accuracy: 0.9983 - val_accuracy: 0.9968 - val_loss: 0.0172 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 276/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.9809 - loss: 0.0694 - precision: 0.9818 - recall: 0.9802 - top_2_accuracy: 0.9952
# Epoch 276: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 442ms/step - accuracy: 0.9809 - loss: 0.0695 - precision: 0.9818 - recall: 0.9801 - top_2_accuracy: 0.9953 - val_accuracy: 0.9968 - val_loss: 0.0175 - val_precision: 0.9968 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 277/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.9765 - loss: 0.0620 - precision: 0.9780 - recall: 0.9754 - top_2_accuracy: 0.9984
# Epoch 277: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 450ms/step - accuracy: 0.9765 - loss: 0.0623 - precision: 0.9779 - recall: 0.9753 - top_2_accuracy: 0.9984 - val_accuracy: 0.9968 - val_loss: 0.0174 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 278/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.9780 - loss: 0.0872 - precision: 0.9790 - recall: 0.9720 - top_2_accuracy: 0.9959
# Epoch 278: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 467ms/step - accuracy: 0.9779 - loss: 0.0873 - precision: 0.9790 - recall: 0.9720 - top_2_accuracy: 0.9960 - val_accuracy: 0.9968 - val_loss: 0.0174 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 279/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.9699 - loss: 0.0917 - precision: 0.9736 - recall: 0.9676 - top_2_accuracy: 0.9960
# Epoch 279: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 28s 546ms/step - accuracy: 0.9700 - loss: 0.0915 - precision: 0.9737 - recall: 0.9676 - top_2_accuracy: 0.9960 - val_accuracy: 0.9968 - val_loss: 0.0172 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 280/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.9785 - loss: 0.0777 - precision: 0.9806 - recall: 0.9728 - top_2_accuracy: 0.9966
# Epoch 280: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 452ms/step - accuracy: 0.9785 - loss: 0.0780 - precision: 0.9806 - recall: 0.9727 - top_2_accuracy: 0.9966 - val_accuracy: 0.9952 - val_loss: 0.0173 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 281/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.9712 - loss: 0.0782 - precision: 0.9757 - recall: 0.9675 - top_2_accuracy: 0.9992
# Epoch 281: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 447ms/step - accuracy: 0.9713 - loss: 0.0783 - precision: 0.9757 - recall: 0.9676 - top_2_accuracy: 0.9991 - val_accuracy: 0.9952 - val_loss: 0.0173 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 282/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.9724 - loss: 0.0619 - precision: 0.9791 - recall: 0.9713 - top_2_accuracy: 0.9979
# Epoch 282: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 443ms/step - accuracy: 0.9724 - loss: 0.0619 - precision: 0.9790 - recall: 0.9713 - top_2_accuracy: 0.9979 - val_accuracy: 0.9952 - val_loss: 0.0170 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 283/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9698 - loss: 0.0776 - precision: 0.9771 - recall: 0.9634 - top_2_accuracy: 0.9955
# Epoch 283: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 432ms/step - accuracy: 0.9698 - loss: 0.0777 - precision: 0.9771 - recall: 0.9635 - top_2_accuracy: 0.9955 - val_accuracy: 0.9952 - val_loss: 0.0171 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 284/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9742 - loss: 0.0763 - precision: 0.9756 - recall: 0.9721 - top_2_accuracy: 1.0000
# Epoch 284: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 433ms/step - accuracy: 0.9742 - loss: 0.0764 - precision: 0.9756 - recall: 0.9720 - top_2_accuracy: 1.0000 - val_accuracy: 0.9952 - val_loss: 0.0171 - val_precision: 0.9968 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 285/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.9776 - loss: 0.0647 - precision: 0.9823 - recall: 0.9748 - top_2_accuracy: 0.9965
# Epoch 285: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 436ms/step - accuracy: 0.9777 - loss: 0.0646 - precision: 0.9823 - recall: 0.9748 - top_2_accuracy: 0.9965 - val_accuracy: 0.9968 - val_loss: 0.0170 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 286/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.9758 - loss: 0.0980 - precision: 0.9781 - recall: 0.9699 - top_2_accuracy: 0.9950
# Epoch 286: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 435ms/step - accuracy: 0.9757 - loss: 0.0979 - precision: 0.9781 - recall: 0.9699 - top_2_accuracy: 0.9950 - val_accuracy: 0.9968 - val_loss: 0.0171 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 287/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.9747 - loss: 0.0723 - precision: 0.9798 - recall: 0.9710 - top_2_accuracy: 0.9942
# Epoch 287: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 435ms/step - accuracy: 0.9747 - loss: 0.0722 - precision: 0.9798 - recall: 0.9711 - top_2_accuracy: 0.9942 - val_accuracy: 0.9968 - val_loss: 0.0171 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 288/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.9764 - loss: 0.0668 - precision: 0.9812 - recall: 0.9734 - top_2_accuracy: 0.9985
# Epoch 288: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 439ms/step - accuracy: 0.9764 - loss: 0.0670 - precision: 0.9812 - recall: 0.9733 - top_2_accuracy: 0.9985 - val_accuracy: 0.9968 - val_loss: 0.0171 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 289/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.9838 - loss: 0.0607 - precision: 0.9849 - recall: 0.9820 - top_2_accuracy: 0.9976
# Epoch 289: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 437ms/step - accuracy: 0.9838 - loss: 0.0608 - precision: 0.9849 - recall: 0.9819 - top_2_accuracy: 0.9976 - val_accuracy: 0.9968 - val_loss: 0.0171 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 290/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.9717 - loss: 0.0716 - precision: 0.9730 - recall: 0.9709 - top_2_accuracy: 0.9963
# Epoch 290: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 435ms/step - accuracy: 0.9717 - loss: 0.0716 - precision: 0.9730 - recall: 0.9709 - top_2_accuracy: 0.9963 - val_accuracy: 0.9968 - val_loss: 0.0169 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 291/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.9788 - loss: 0.0710 - precision: 0.9794 - recall: 0.9764 - top_2_accuracy: 0.9978
# Epoch 291: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 449ms/step - accuracy: 0.9788 - loss: 0.0709 - precision: 0.9795 - recall: 0.9764 - top_2_accuracy: 0.9978 - val_accuracy: 0.9968 - val_loss: 0.0170 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 292/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.9779 - loss: 0.0660 - precision: 0.9827 - recall: 0.9747 - top_2_accuracy: 0.9949
# Epoch 292: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 447ms/step - accuracy: 0.9779 - loss: 0.0660 - precision: 0.9827 - recall: 0.9747 - top_2_accuracy: 0.9949 - val_accuracy: 0.9968 - val_loss: 0.0170 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 293/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.9809 - loss: 0.0597 - precision: 0.9826 - recall: 0.9789 - top_2_accuracy: 0.9973
# Epoch 293: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 445ms/step - accuracy: 0.9809 - loss: 0.0598 - precision: 0.9826 - recall: 0.9789 - top_2_accuracy: 0.9973 - val_accuracy: 0.9968 - val_loss: 0.0171 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 294/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.9894 - loss: 0.0500 - precision: 0.9895 - recall: 0.9868 - top_2_accuracy: 0.9987
# Epoch 294: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 453ms/step - accuracy: 0.9893 - loss: 0.0502 - precision: 0.9894 - recall: 0.9867 - top_2_accuracy: 0.9987 - val_accuracy: 0.9968 - val_loss: 0.0170 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 295/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 401ms/step - accuracy: 0.9782 - loss: 0.0696 - precision: 0.9794 - recall: 0.9737 - top_2_accuracy: 0.9987
# Epoch 295: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 429ms/step - accuracy: 0.9782 - loss: 0.0695 - precision: 0.9795 - recall: 0.9737 - top_2_accuracy: 0.9987 - val_accuracy: 0.9968 - val_loss: 0.0170 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 296/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.9663 - loss: 0.0924 - precision: 0.9689 - recall: 0.9652 - top_2_accuracy: 0.9970
# Epoch 296: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 441ms/step - accuracy: 0.9663 - loss: 0.0924 - precision: 0.9689 - recall: 0.9652 - top_2_accuracy: 0.9970 - val_accuracy: 0.9968 - val_loss: 0.0172 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 297/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.9810 - loss: 0.0649 - precision: 0.9826 - recall: 0.9744 - top_2_accuracy: 0.9983
# Epoch 297: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 452ms/step - accuracy: 0.9810 - loss: 0.0650 - precision: 0.9826 - recall: 0.9744 - top_2_accuracy: 0.9983 - val_accuracy: 0.9952 - val_loss: 0.0171 - val_precision: 0.9952 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 298/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.9712 - loss: 0.0940 - precision: 0.9758 - recall: 0.9700 - top_2_accuracy: 0.9969
# Epoch 298: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 25s 472ms/step - accuracy: 0.9713 - loss: 0.0938 - precision: 0.9759 - recall: 0.9701 - top_2_accuracy: 0.9969 - val_accuracy: 0.9968 - val_loss: 0.0171 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 299/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.9804 - loss: 0.0573 - precision: 0.9828 - recall: 0.9737 - top_2_accuracy: 0.9989
# Epoch 299: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 448ms/step - accuracy: 0.9805 - loss: 0.0573 - precision: 0.9828 - recall: 0.9738 - top_2_accuracy: 0.9989 - val_accuracy: 0.9968 - val_loss: 0.0173 - val_precision: 0.9968 - val_recall: 0.9968 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 300/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step - accuracy: 0.9747 - loss: 0.0674 - precision: 0.9790 - recall: 0.9690 - top_2_accuracy: 0.9995
# Epoch 300: val_loss did not improve from 0.01654
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 426ms/step - accuracy: 0.9747 - loss: 0.0674 - precision: 0.9790 - recall: 0.9691 - top_2_accuracy: 0.9995 - val_accuracy: 0.9952 - val_loss: 0.0172 - val_precision: 0.9968 - val_recall: 0.9952 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Restoring model weights from the end of the best epoch: 176.
#
# PHASE-01: Training Completed Successfully!!!!
#
# ============================================================
# Final Train Loss: [0.06606835871934891]
# Best Train Loss: [0.0543828047811985]
# Final Train Accuracy: [0.9768292903900146]
# Best Train Accuracy: [0.9853658676147461]
# ============================================================
# Final Validation Loss: [0.0171770378947258]
# Best Validation Loss: [0.016535740345716476]
# Final Validation Accuracy: [0.9951612949371338]
# Best Validation Accuracy: [0.9967741966247559]
# ============================================================

# %% [markdown]
# #### **Check For Overfitting Or Underfitting :**

# %%
best_train_acc = max(history_frozen.history['accuracy'])
best_val_acc = max(history_frozen.history['val_accuracy'])
dif = best_train_acc - best_val_acc

if dif > 0.1:
    print(f"Warning: Large gap [{dif:.3f}] between train and validation accuracy suggests overfitting!!!.")
elif dif < -0.1:
    print(f"Warning: Large gap [{dif:.3f}] between train and validation accuracy suggests underfitting!!!.")
else:
    print(f"Good Fit: Gap between train and validation accuracy is [{dif:.3f}]s.")
# Out:
# Good Fit: Gap between train and validation accuracy is [-0.011]s.

# %% [markdown]
# # **Fine Tune By Unfreezing Top Layers :**

# %%
def train_by_unfreezing_top_layers(train_gen, val_gen, new_model, base_model, checkpoint_model_save_path, 
                                   final_model_save_path, fine_initial_lr, epochs_fine, #class_weights
                                  ):
    
    # Recompile model with lower learning rate
    new_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=fine_initial_lr),
                      loss='categorical_crossentropy',
                      metrics=['accuracy',
                               tf.keras.metrics.TopKCategoricalAccuracy(k=2, name='top_2_accuracy'),
                               tf.keras.metrics.Precision(name='precision'),
                                tf.keras.metrics.Recall(name='recall')])
    
    # Define callbacks for fine tune
    callbacks = [EarlyStopping(monitor='val_loss', patience=300, restore_best_weights=True, verbose=1),
                 ModelCheckpoint(checkpoint_model_save_path, monitor='val_loss', save_best_only=True, verbose=1),
                 ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.0000001, verbose=1)]
    
    # Fine tune by unfreezing top layers 
    base_model.trainable = True
    
    # Fine tune from this layer onwards
    fine_tune_at = len(base_model.layers) - 30 
    
    # Freeze all layers except the last few
    for layer in base_model.layers[:fine_tune_at]:
        layer.trainable = False

    print("\n" + "="*60)
    print("Phase-02: Fine Tune By Unfreezing Top Layers ...........")
    print(f"Initial Learning Rate: [{fine_initial_lr}]")
    print(f"Epochs: [{epochs_fine}]")
    print(f"Total Layers: [{len(base_model.layers)}]")
    print(f"Trainable Parameters: [{sum([tf.keras.backend.count_params(w) for w in new_model.trainable_weights])}]") 
    print(f"Fine tune from layer [{fine_tune_at}] onwards.")
    print(f"Trainable layers [{sum(1 for layer in base_model.layers if layer.trainable) }]")
    print("="*60)
    
    # Fit the new model 
    try:
        history_fine_tune = new_model.fit(train_gen, validation_data=val_gen, epochs=epochs_fine, callbacks=callbacks, # class_weight=class_weights
                                       verbose=1)
        print(f"\nPHASE-02: Training Completed Successfully!!!!\n")
    except Exception as e:
        print(f"\nWarning: PHASE-02: Training Failed With Error: {e}")
        print("Please Check Your Data Generators, Model Architecture And Parameters.")
        return None

    # For train summary
    print("="*60)
    print(f"Final Train Loss: [{history_fine_tune.history['loss'][-1]}]")
    print(f"Best Train Loss: [{min(history_fine_tune.history['loss'])}]")
    print(f"Final Train Accuracy: [{history_fine_tune.history['accuracy'][-1]}]")
    print(f"Best Train Accuracy: [{max(history_fine_tune.history['accuracy'])}]")
    print("="*60)
    
    # For validation summary
    print(f"Final Validation Loss: [{history_fine_tune.history['val_loss'][-1]}]")
    print(f"Best Validation Loss: [{min(history_fine_tune.history['val_loss'])}]")
    print(f"Final Validation Accuracy: [{history_fine_tune.history['val_accuracy'][-1]}]")
    print(f"Best Validation Accuracy: [{max(history_fine_tune.history['val_accuracy'])}]")
    print("="*60 + "\n")
    
    # Save the final fine tune model
    new_model.save(os.path.join(final_model_save_path, 'final_fine_tune_best.h5'))
    
    return history_fine_tune

# %%
history_fine_tune = train_by_unfreezing_top_layers(train_gen=train_gen,
                               val_gen=val_gen,
                               new_model=new_model,
                               base_model=base_model,
                               checkpoint_model_save_path="/kaggle/working/ModelCheckpoints/fine_tune.h5", 
                               final_model_save_path="/kaggle/working/weights", 
                               fine_initial_lr=0.0000001,
                               epochs_fine=300, 
                               # class_weights=class_weights_dict
                               )
# Out:
# ============================================================
# Phase-02: Fine Tune By Unfreezing Top Layers ...........
# Initial Learning Rate: [1e-07]
# Epochs: [300]
# Total Layers: [154]
# Trainable Parameters: [3530502]
# Fine tune from layer [124] onwards.
# Trainable layers [30]
# ============================================================
# Epoch 1/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 530ms/step - accuracy: 0.8713 - loss: 0.5381 - precision: 0.8816 - recall: 0.8434 - top_2_accuracy: 0.9521
# Epoch 1: val_loss improved from inf to 0.02076, saving model to /kaggle/working/ModelCheckpoints/fine_tune.h5
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 59s 697ms/step - accuracy: 0.8711 - loss: 0.5379 - precision: 0.8816 - recall: 0.8435 - top_2_accuracy: 0.9519 - val_accuracy: 0.9935 - val_loss: 0.0208 - val_precision: 0.9952 - val_recall: 0.9935 - val_top_2_accuracy: 1.0000 - learning_rate: 1.0000e-07
# Epoch 2/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8574 - loss: 0.5373 - precision: 0.8785 - recall: 0.8404 - top_2_accuracy: 0.9586
# Epoch 2: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 439ms/step - accuracy: 0.8574 - loss: 0.5367 - precision: 0.8786 - recall: 0.8404 - top_2_accuracy: 0.9585 - val_accuracy: 0.9855 - val_loss: 0.0338 - val_precision: 0.9871 - val_recall: 0.9855 - val_top_2_accuracy: 0.9984 - learning_rate: 1.0000e-07
# Epoch 3/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.8714 - loss: 0.4561 - precision: 0.8884 - recall: 0.8497 - top_2_accuracy: 0.9589
# Epoch 3: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 434ms/step - accuracy: 0.8711 - loss: 0.4574 - precision: 0.8881 - recall: 0.8494 - top_2_accuracy: 0.9587 - val_accuracy: 0.9823 - val_loss: 0.0467 - val_precision: 0.9823 - val_recall: 0.9823 - val_top_2_accuracy: 0.9968 - learning_rate: 1.0000e-07
# Epoch 4/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.8422 - loss: 0.5560 - precision: 0.8577 - recall: 0.8229 - top_2_accuracy: 0.9428
# Epoch 4: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 439ms/step - accuracy: 0.8422 - loss: 0.5558 - precision: 0.8577 - recall: 0.8230 - top_2_accuracy: 0.9428 - val_accuracy: 0.9806 - val_loss: 0.0571 - val_precision: 0.9806 - val_recall: 0.9790 - val_top_2_accuracy: 0.9968 - learning_rate: 1.0000e-07
# Epoch 5/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.8761 - loss: 0.4281 - precision: 0.8930 - recall: 0.8552 - top_2_accuracy: 0.9558
# Epoch 5: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 448ms/step - accuracy: 0.8760 - loss: 0.4289 - precision: 0.8929 - recall: 0.8552 - top_2_accuracy: 0.9557 - val_accuracy: 0.9774 - val_loss: 0.0638 - val_precision: 0.9774 - val_recall: 0.9774 - val_top_2_accuracy: 0.9968 - learning_rate: 1.0000e-07
# Epoch 6/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.8553 - loss: 0.5306 - precision: 0.8793 - recall: 0.8395 - top_2_accuracy: 0.9496
# Epoch 6: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 450ms/step - accuracy: 0.8551 - loss: 0.5313 - precision: 0.8792 - recall: 0.8393 - top_2_accuracy: 0.9495 - val_accuracy: 0.9774 - val_loss: 0.0661 - val_precision: 0.9774 - val_recall: 0.9774 - val_top_2_accuracy: 0.9968 - learning_rate: 1.0000e-07
# Epoch 7/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.8463 - loss: 0.5590 - precision: 0.8655 - recall: 0.8289 - top_2_accuracy: 0.9414
# Epoch 7: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 445ms/step - accuracy: 0.8465 - loss: 0.5582 - precision: 0.8656 - recall: 0.8291 - top_2_accuracy: 0.9415 - val_accuracy: 0.9774 - val_loss: 0.0671 - val_precision: 0.9774 - val_recall: 0.9774 - val_top_2_accuracy: 0.9968 - learning_rate: 1.0000e-07
# Epoch 8/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8602 - loss: 0.5507 - precision: 0.8777 - recall: 0.8425 - top_2_accuracy: 0.9522
# Epoch 8: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 439ms/step - accuracy: 0.8603 - loss: 0.5500 - precision: 0.8777 - recall: 0.8426 - top_2_accuracy: 0.9522 - val_accuracy: 0.9774 - val_loss: 0.0671 - val_precision: 0.9774 - val_recall: 0.9774 - val_top_2_accuracy: 0.9968 - learning_rate: 1.0000e-07
# Epoch 9/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.8424 - loss: 0.5398 - precision: 0.8559 - recall: 0.8252 - top_2_accuracy: 0.9516
# Epoch 9: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 452ms/step - accuracy: 0.8426 - loss: 0.5389 - precision: 0.8561 - recall: 0.8255 - top_2_accuracy: 0.9517 - val_accuracy: 0.9774 - val_loss: 0.0681 - val_precision: 0.9774 - val_recall: 0.9774 - val_top_2_accuracy: 0.9968 - learning_rate: 1.0000e-07
# Epoch 10/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.8624 - loss: 0.5151 - precision: 0.8762 - recall: 0.8324 - top_2_accuracy: 0.9517
# Epoch 10: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 439ms/step - accuracy: 0.8625 - loss: 0.5144 - precision: 0.8763 - recall: 0.8327 - top_2_accuracy: 0.9518 - val_accuracy: 0.9790 - val_loss: 0.0679 - val_precision: 0.9790 - val_recall: 0.9790 - val_top_2_accuracy: 0.9968 - learning_rate: 1.0000e-07
# Epoch 11/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step - accuracy: 0.8575 - loss: 0.4832 - precision: 0.8790 - recall: 0.8374 - top_2_accuracy: 0.9464
# Epoch 11: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 29s 551ms/step - accuracy: 0.8574 - loss: 0.4833 - precision: 0.8789 - recall: 0.8373 - top_2_accuracy: 0.9466 - val_accuracy: 0.9790 - val_loss: 0.0685 - val_precision: 0.9790 - val_recall: 0.9790 - val_top_2_accuracy: 0.9968 - learning_rate: 1.0000e-07
# Epoch 12/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 507ms/step - accuracy: 0.8584 - loss: 0.4896 - precision: 0.8755 - recall: 0.8441 - top_2_accuracy: 0.9602
# Epoch 12: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 29s 560ms/step - accuracy: 0.8583 - loss: 0.4899 - precision: 0.8754 - recall: 0.8440 - top_2_accuracy: 0.9601 - val_accuracy: 0.9774 - val_loss: 0.0698 - val_precision: 0.9774 - val_recall: 0.9774 - val_top_2_accuracy: 0.9968 - learning_rate: 1.0000e-07
# Epoch 13/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 527ms/step - accuracy: 0.8679 - loss: 0.4246 - precision: 0.8894 - recall: 0.8518 - top_2_accuracy: 0.9595
# Epoch 13: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 31s 593ms/step - accuracy: 0.8676 - loss: 0.4257 - precision: 0.8891 - recall: 0.8515 - top_2_accuracy: 0.9595 - val_accuracy: 0.9742 - val_loss: 0.0717 - val_precision: 0.9758 - val_recall: 0.9742 - val_top_2_accuracy: 0.9968 - learning_rate: 1.0000e-07
# Epoch 14/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step - accuracy: 0.8648 - loss: 0.4658 - precision: 0.8807 - recall: 0.8522 - top_2_accuracy: 0.9536
# Epoch 14: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 27s 514ms/step - accuracy: 0.8645 - loss: 0.4669 - precision: 0.8804 - recall: 0.8517 - top_2_accuracy: 0.9535 - val_accuracy: 0.9742 - val_loss: 0.0727 - val_precision: 0.9757 - val_recall: 0.9726 - val_top_2_accuracy: 0.9968 - learning_rate: 1.0000e-07
# Epoch 15/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.8527 - loss: 0.5618 - precision: 0.8714 - recall: 0.8333 - top_2_accuracy: 0.9521
# Epoch 15: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 441ms/step - accuracy: 0.8529 - loss: 0.5600 - precision: 0.8717 - recall: 0.8336 - top_2_accuracy: 0.9522 - val_accuracy: 0.9742 - val_loss: 0.0741 - val_precision: 0.9741 - val_recall: 0.9710 - val_top_2_accuracy: 0.9968 - learning_rate: 1.0000e-07
# Epoch 16/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.8699 - loss: 0.4916 - precision: 0.8967 - recall: 0.8469 - top_2_accuracy: 0.9554
# Epoch 16: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 441ms/step - accuracy: 0.8699 - loss: 0.4915 - precision: 0.8966 - recall: 0.8468 - top_2_accuracy: 0.9554 - val_accuracy: 0.9742 - val_loss: 0.0756 - val_precision: 0.9742 - val_recall: 0.9726 - val_top_2_accuracy: 0.9968 - learning_rate: 1.0000e-07
# Epoch 17/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.8930 - loss: 0.3935 - precision: 0.9101 - recall: 0.8694 - top_2_accuracy: 0.9619
# Epoch 17: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 443ms/step - accuracy: 0.8925 - loss: 0.3953 - precision: 0.9096 - recall: 0.8689 - top_2_accuracy: 0.9618 - val_accuracy: 0.9710 - val_loss: 0.0778 - val_precision: 0.9741 - val_recall: 0.9694 - val_top_2_accuracy: 0.9952 - learning_rate: 1.0000e-07
# Epoch 18/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.8701 - loss: 0.4622 - precision: 0.8831 - recall: 0.8433 - top_2_accuracy: 0.9580
# Epoch 18: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 450ms/step - accuracy: 0.8700 - loss: 0.4624 - precision: 0.8832 - recall: 0.8433 - top_2_accuracy: 0.9580 - val_accuracy: 0.9710 - val_loss: 0.0799 - val_precision: 0.9740 - val_recall: 0.9661 - val_top_2_accuracy: 0.9952 - learning_rate: 1.0000e-07
# Epoch 19/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.8479 - loss: 0.5064 - precision: 0.8784 - recall: 0.8266 - top_2_accuracy: 0.9466
# Epoch 19: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 442ms/step - accuracy: 0.8478 - loss: 0.5066 - precision: 0.8783 - recall: 0.8266 - top_2_accuracy: 0.9466 - val_accuracy: 0.9694 - val_loss: 0.0830 - val_precision: 0.9740 - val_recall: 0.9661 - val_top_2_accuracy: 0.9952 - learning_rate: 1.0000e-07
# Epoch 20/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.8545 - loss: 0.5617 - precision: 0.8678 - recall: 0.8375 - top_2_accuracy: 0.9542
# Epoch 20: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 432ms/step - accuracy: 0.8546 - loss: 0.5609 - precision: 0.8680 - recall: 0.8377 - top_2_accuracy: 0.9542 - val_accuracy: 0.9694 - val_loss: 0.0861 - val_precision: 0.9725 - val_recall: 0.9694 - val_top_2_accuracy: 0.9952 - learning_rate: 1.0000e-07
# Epoch 21/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.8543 - loss: 0.5286 - precision: 0.8827 - recall: 0.8397 - top_2_accuracy: 0.9453
# Epoch 21: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 442ms/step - accuracy: 0.8542 - loss: 0.5289 - precision: 0.8825 - recall: 0.8397 - top_2_accuracy: 0.9454 - val_accuracy: 0.9710 - val_loss: 0.0889 - val_precision: 0.9740 - val_recall: 0.9677 - val_top_2_accuracy: 0.9952 - learning_rate: 1.0000e-07
# Epoch 22/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step - accuracy: 0.8773 - loss: 0.4094 - precision: 0.9007 - recall: 0.8603 - top_2_accuracy: 0.9575
# Epoch 22: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 461ms/step - accuracy: 0.8771 - loss: 0.4102 - precision: 0.9004 - recall: 0.8601 - top_2_accuracy: 0.9574 - val_accuracy: 0.9694 - val_loss: 0.0925 - val_precision: 0.9739 - val_recall: 0.9645 - val_top_2_accuracy: 0.9952 - learning_rate: 1.0000e-07
# Epoch 23/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.8799 - loss: 0.3962 - precision: 0.8976 - recall: 0.8603 - top_2_accuracy: 0.9627
# Epoch 23: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 440ms/step - accuracy: 0.8798 - loss: 0.3969 - precision: 0.8975 - recall: 0.8601 - top_2_accuracy: 0.9626 - val_accuracy: 0.9645 - val_loss: 0.0962 - val_precision: 0.9707 - val_recall: 0.9629 - val_top_2_accuracy: 0.9935 - learning_rate: 1.0000e-07
# Epoch 24/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.8466 - loss: 0.5554 - precision: 0.8650 - recall: 0.8280 - top_2_accuracy: 0.9488
# Epoch 24: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 444ms/step - accuracy: 0.8468 - loss: 0.5548 - precision: 0.8651 - recall: 0.8282 - top_2_accuracy: 0.9488 - val_accuracy: 0.9613 - val_loss: 0.1005 - val_precision: 0.9691 - val_recall: 0.9613 - val_top_2_accuracy: 0.9919 - learning_rate: 1.0000e-07
# Epoch 25/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8679 - loss: 0.4559 - precision: 0.8935 - recall: 0.8519 - top_2_accuracy: 0.9532
# Epoch 25: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 439ms/step - accuracy: 0.8678 - loss: 0.4563 - precision: 0.8934 - recall: 0.8518 - top_2_accuracy: 0.9531 - val_accuracy: 0.9613 - val_loss: 0.1045 - val_precision: 0.9660 - val_recall: 0.9613 - val_top_2_accuracy: 0.9919 - learning_rate: 1.0000e-07
# Epoch 26/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.8717 - loss: 0.4775 - precision: 0.8855 - recall: 0.8462 - top_2_accuracy: 0.9523
# Epoch 26: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 437ms/step - accuracy: 0.8715 - loss: 0.4784 - precision: 0.8853 - recall: 0.8460 - top_2_accuracy: 0.9523 - val_accuracy: 0.9597 - val_loss: 0.1104 - val_precision: 0.9627 - val_recall: 0.9565 - val_top_2_accuracy: 0.9919 - learning_rate: 1.0000e-07
# Epoch 27/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.8610 - loss: 0.4238 - precision: 0.8882 - recall: 0.8486 - top_2_accuracy: 0.9582
# Epoch 27: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 446ms/step - accuracy: 0.8611 - loss: 0.4248 - precision: 0.8881 - recall: 0.8485 - top_2_accuracy: 0.9581 - val_accuracy: 0.9613 - val_loss: 0.1151 - val_precision: 0.9627 - val_recall: 0.9565 - val_top_2_accuracy: 0.9903 - learning_rate: 1.0000e-07
# Epoch 28/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.8686 - loss: 0.4541 - precision: 0.8839 - recall: 0.8500 - top_2_accuracy: 0.9639
# Epoch 28: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 456ms/step - accuracy: 0.8684 - loss: 0.4553 - precision: 0.8838 - recall: 0.8498 - top_2_accuracy: 0.9638 - val_accuracy: 0.9581 - val_loss: 0.1206 - val_precision: 0.9610 - val_recall: 0.9532 - val_top_2_accuracy: 0.9903 - learning_rate: 1.0000e-07
# Epoch 29/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step - accuracy: 0.8504 - loss: 0.4811 - precision: 0.8672 - recall: 0.8327 - top_2_accuracy: 0.9532
# Epoch 29: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 25s 486ms/step - accuracy: 0.8504 - loss: 0.4809 - precision: 0.8673 - recall: 0.8327 - top_2_accuracy: 0.9532 - val_accuracy: 0.9565 - val_loss: 0.1252 - val_precision: 0.9577 - val_recall: 0.9500 - val_top_2_accuracy: 0.9903 - learning_rate: 1.0000e-07
# Epoch 30/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step - accuracy: 0.8802 - loss: 0.4210 - precision: 0.8973 - recall: 0.8647 - top_2_accuracy: 0.9620
# Epoch 30: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 26s 489ms/step - accuracy: 0.8801 - loss: 0.4214 - precision: 0.8971 - recall: 0.8646 - top_2_accuracy: 0.9619 - val_accuracy: 0.9548 - val_loss: 0.1299 - val_precision: 0.9592 - val_recall: 0.9468 - val_top_2_accuracy: 0.9903 - learning_rate: 1.0000e-07
# Epoch 31/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8738 - loss: 0.4240 - precision: 0.8943 - recall: 0.8548 - top_2_accuracy: 0.9582
# Epoch 31: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 437ms/step - accuracy: 0.8734 - loss: 0.4254 - precision: 0.8939 - recall: 0.8545 - top_2_accuracy: 0.9581 - val_accuracy: 0.9532 - val_loss: 0.1346 - val_precision: 0.9606 - val_recall: 0.9435 - val_top_2_accuracy: 0.9903 - learning_rate: 1.0000e-07
# Epoch 32/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8674 - loss: 0.5015 - precision: 0.8808 - recall: 0.8434 - top_2_accuracy: 0.9580
# Epoch 32: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 433ms/step - accuracy: 0.8674 - loss: 0.5016 - precision: 0.8808 - recall: 0.8435 - top_2_accuracy: 0.9579 - val_accuracy: 0.9516 - val_loss: 0.1392 - val_precision: 0.9573 - val_recall: 0.9403 - val_top_2_accuracy: 0.9903 - learning_rate: 1.0000e-07
# Epoch 33/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8664 - loss: 0.4589 - precision: 0.8816 - recall: 0.8458 - top_2_accuracy: 0.9620
# Epoch 33: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 437ms/step - accuracy: 0.8662 - loss: 0.4597 - precision: 0.8815 - recall: 0.8456 - top_2_accuracy: 0.9619 - val_accuracy: 0.9516 - val_loss: 0.1437 - val_precision: 0.9558 - val_recall: 0.9419 - val_top_2_accuracy: 0.9903 - learning_rate: 1.0000e-07
# Epoch 34/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.8620 - loss: 0.4623 - precision: 0.8778 - recall: 0.8412 - top_2_accuracy: 0.9477
# Epoch 34: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 437ms/step - accuracy: 0.8619 - loss: 0.4630 - precision: 0.8777 - recall: 0.8411 - top_2_accuracy: 0.9477 - val_accuracy: 0.9500 - val_loss: 0.1477 - val_precision: 0.9557 - val_recall: 0.9403 - val_top_2_accuracy: 0.9903 - learning_rate: 1.0000e-07
# Epoch 35/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.8643 - loss: 0.5236 - precision: 0.8745 - recall: 0.8480 - top_2_accuracy: 0.9500
# Epoch 35: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 445ms/step - accuracy: 0.8642 - loss: 0.5232 - precision: 0.8745 - recall: 0.8479 - top_2_accuracy: 0.9500 - val_accuracy: 0.9468 - val_loss: 0.1512 - val_precision: 0.9556 - val_recall: 0.9371 - val_top_2_accuracy: 0.9903 - learning_rate: 1.0000e-07
# Epoch 36/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.8728 - loss: 0.4130 - precision: 0.8965 - recall: 0.8588 - top_2_accuracy: 0.9650
# Epoch 36: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 434ms/step - accuracy: 0.8728 - loss: 0.4134 - precision: 0.8965 - recall: 0.8588 - top_2_accuracy: 0.9648 - val_accuracy: 0.9468 - val_loss: 0.1550 - val_precision: 0.9539 - val_recall: 0.9339 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 37/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8539 - loss: 0.5042 - precision: 0.8736 - recall: 0.8435 - top_2_accuracy: 0.9500
# Epoch 37: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 438ms/step - accuracy: 0.8540 - loss: 0.5034 - precision: 0.8737 - recall: 0.8435 - top_2_accuracy: 0.9500 - val_accuracy: 0.9452 - val_loss: 0.1584 - val_precision: 0.9523 - val_recall: 0.9339 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 38/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step - accuracy: 0.8664 - loss: 0.4637 - precision: 0.8858 - recall: 0.8535 - top_2_accuracy: 0.9516
# Epoch 38: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 27s 526ms/step - accuracy: 0.8665 - loss: 0.4635 - precision: 0.8858 - recall: 0.8535 - top_2_accuracy: 0.9516 - val_accuracy: 0.9452 - val_loss: 0.1616 - val_precision: 0.9523 - val_recall: 0.9339 - val_top_2_accuracy: 0.9871 - learning_rate: 1.0000e-07
# Epoch 39/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 521ms/step - accuracy: 0.8591 - loss: 0.5411 - precision: 0.8762 - recall: 0.8396 - top_2_accuracy: 0.9554
# Epoch 39: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 31s 593ms/step - accuracy: 0.8592 - loss: 0.5402 - precision: 0.8762 - recall: 0.8397 - top_2_accuracy: 0.9554 - val_accuracy: 0.9452 - val_loss: 0.1654 - val_precision: 0.9523 - val_recall: 0.9339 - val_top_2_accuracy: 0.9871 - learning_rate: 1.0000e-07
# Epoch 40/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 452ms/step - accuracy: 0.8662 - loss: 0.4575 - precision: 0.8849 - recall: 0.8434 - top_2_accuracy: 0.9562
# Epoch 40: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 25s 480ms/step - accuracy: 0.8663 - loss: 0.4574 - precision: 0.8850 - recall: 0.8436 - top_2_accuracy: 0.9563 - val_accuracy: 0.9403 - val_loss: 0.1681 - val_precision: 0.9505 - val_recall: 0.9290 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 41/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8772 - loss: 0.4226 - precision: 0.8967 - recall: 0.8639 - top_2_accuracy: 0.9588
# Epoch 41: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 439ms/step - accuracy: 0.8771 - loss: 0.4229 - precision: 0.8966 - recall: 0.8637 - top_2_accuracy: 0.9589 - val_accuracy: 0.9419 - val_loss: 0.1711 - val_precision: 0.9521 - val_recall: 0.9306 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 42/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8543 - loss: 0.4871 - precision: 0.8872 - recall: 0.8403 - top_2_accuracy: 0.9444
# Epoch 42: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 438ms/step - accuracy: 0.8543 - loss: 0.4874 - precision: 0.8870 - recall: 0.8403 - top_2_accuracy: 0.9444 - val_accuracy: 0.9387 - val_loss: 0.1738 - val_precision: 0.9505 - val_recall: 0.9290 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 43/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.8808 - loss: 0.5177 - precision: 0.8918 - recall: 0.8589 - top_2_accuracy: 0.9555
# Epoch 43: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 446ms/step - accuracy: 0.8809 - loss: 0.5167 - precision: 0.8920 - recall: 0.8590 - top_2_accuracy: 0.9556 - val_accuracy: 0.9371 - val_loss: 0.1765 - val_precision: 0.9474 - val_recall: 0.9290 - val_top_2_accuracy: 0.9871 - learning_rate: 1.0000e-07
# Epoch 44/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.8493 - loss: 0.5544 - precision: 0.8659 - recall: 0.8332 - top_2_accuracy: 0.9416
# Epoch 44: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 440ms/step - accuracy: 0.8494 - loss: 0.5535 - precision: 0.8660 - recall: 0.8333 - top_2_accuracy: 0.9416 - val_accuracy: 0.9355 - val_loss: 0.1795 - val_precision: 0.9458 - val_recall: 0.9290 - val_top_2_accuracy: 0.9871 - learning_rate: 1.0000e-07
# Epoch 45/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.8778 - loss: 0.4034 - precision: 0.8933 - recall: 0.8619 - top_2_accuracy: 0.9661
# Epoch 45: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 434ms/step - accuracy: 0.8776 - loss: 0.4038 - precision: 0.8932 - recall: 0.8617 - top_2_accuracy: 0.9660 - val_accuracy: 0.9339 - val_loss: 0.1817 - val_precision: 0.9457 - val_recall: 0.9274 - val_top_2_accuracy: 0.9871 - learning_rate: 1.0000e-07
# Epoch 46/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.8523 - loss: 0.4982 - precision: 0.8701 - recall: 0.8369 - top_2_accuracy: 0.9574
# Epoch 46: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 434ms/step - accuracy: 0.8525 - loss: 0.4979 - precision: 0.8703 - recall: 0.8371 - top_2_accuracy: 0.9575 - val_accuracy: 0.9339 - val_loss: 0.1844 - val_precision: 0.9426 - val_recall: 0.9274 - val_top_2_accuracy: 0.9855 - learning_rate: 1.0000e-07
# Epoch 47/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8853 - loss: 0.4158 - precision: 0.9056 - recall: 0.8706 - top_2_accuracy: 0.9605
# Epoch 47: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 440ms/step - accuracy: 0.8852 - loss: 0.4161 - precision: 0.9055 - recall: 0.8704 - top_2_accuracy: 0.9606 - val_accuracy: 0.9323 - val_loss: 0.1868 - val_precision: 0.9426 - val_recall: 0.9274 - val_top_2_accuracy: 0.9855 - learning_rate: 1.0000e-07
# Epoch 48/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.8515 - loss: 0.4816 - precision: 0.8767 - recall: 0.8387 - top_2_accuracy: 0.9527
# Epoch 48: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 438ms/step - accuracy: 0.8515 - loss: 0.4813 - precision: 0.8768 - recall: 0.8387 - top_2_accuracy: 0.9527 - val_accuracy: 0.9323 - val_loss: 0.1892 - val_precision: 0.9409 - val_recall: 0.9242 - val_top_2_accuracy: 0.9855 - learning_rate: 1.0000e-07
# Epoch 49/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8809 - loss: 0.4383 - precision: 0.8973 - recall: 0.8656 - top_2_accuracy: 0.9654
# Epoch 49: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 439ms/step - accuracy: 0.8809 - loss: 0.4385 - precision: 0.8972 - recall: 0.8656 - top_2_accuracy: 0.9653 - val_accuracy: 0.9339 - val_loss: 0.1903 - val_precision: 0.9407 - val_recall: 0.9210 - val_top_2_accuracy: 0.9855 - learning_rate: 1.0000e-07
# Epoch 50/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 445ms/step - accuracy: 0.8662 - loss: 0.4511 - precision: 0.8841 - recall: 0.8420 - top_2_accuracy: 0.9614
# Epoch 50: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 25s 477ms/step - accuracy: 0.8661 - loss: 0.4513 - precision: 0.8840 - recall: 0.8420 - top_2_accuracy: 0.9614 - val_accuracy: 0.9323 - val_loss: 0.1923 - val_precision: 0.9407 - val_recall: 0.9210 - val_top_2_accuracy: 0.9855 - learning_rate: 1.0000e-07
# Epoch 51/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step - accuracy: 0.8692 - loss: 0.4855 - precision: 0.8830 - recall: 0.8390 - top_2_accuracy: 0.9528
# Epoch 51: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 456ms/step - accuracy: 0.8693 - loss: 0.4854 - precision: 0.8831 - recall: 0.8392 - top_2_accuracy: 0.9529 - val_accuracy: 0.9306 - val_loss: 0.1943 - val_precision: 0.9407 - val_recall: 0.9210 - val_top_2_accuracy: 0.9855 - learning_rate: 1.0000e-07
# Epoch 52/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.8774 - loss: 0.4593 - precision: 0.8998 - recall: 0.8506 - top_2_accuracy: 0.9518
# Epoch 52: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 440ms/step - accuracy: 0.8773 - loss: 0.4593 - precision: 0.8995 - recall: 0.8505 - top_2_accuracy: 0.9519 - val_accuracy: 0.9290 - val_loss: 0.1963 - val_precision: 0.9406 - val_recall: 0.9194 - val_top_2_accuracy: 0.9855 - learning_rate: 1.0000e-07
# Epoch 53/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.8621 - loss: 0.4463 - precision: 0.8854 - recall: 0.8484 - top_2_accuracy: 0.9570
# Epoch 53: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 438ms/step - accuracy: 0.8623 - loss: 0.4459 - precision: 0.8855 - recall: 0.8485 - top_2_accuracy: 0.9570 - val_accuracy: 0.9306 - val_loss: 0.1978 - val_precision: 0.9407 - val_recall: 0.9210 - val_top_2_accuracy: 0.9855 - learning_rate: 1.0000e-07
# Epoch 54/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8712 - loss: 0.4666 - precision: 0.8887 - recall: 0.8538 - top_2_accuracy: 0.9598
# Epoch 54: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 437ms/step - accuracy: 0.8711 - loss: 0.4668 - precision: 0.8887 - recall: 0.8537 - top_2_accuracy: 0.9597 - val_accuracy: 0.9306 - val_loss: 0.1998 - val_precision: 0.9387 - val_recall: 0.9145 - val_top_2_accuracy: 0.9855 - learning_rate: 1.0000e-07
# Epoch 55/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.8742 - loss: 0.4714 - precision: 0.8878 - recall: 0.8563 - top_2_accuracy: 0.9542
# Epoch 55: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 435ms/step - accuracy: 0.8740 - loss: 0.4714 - precision: 0.8876 - recall: 0.8562 - top_2_accuracy: 0.9542 - val_accuracy: 0.9290 - val_loss: 0.2013 - val_precision: 0.9370 - val_recall: 0.9113 - val_top_2_accuracy: 0.9855 - learning_rate: 1.0000e-07
# Epoch 56/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.8627 - loss: 0.4668 - precision: 0.8887 - recall: 0.8422 - top_2_accuracy: 0.9464
# Epoch 56: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 434ms/step - accuracy: 0.8628 - loss: 0.4666 - precision: 0.8887 - recall: 0.8423 - top_2_accuracy: 0.9466 - val_accuracy: 0.9274 - val_loss: 0.2032 - val_precision: 0.9371 - val_recall: 0.9129 - val_top_2_accuracy: 0.9855 - learning_rate: 1.0000e-07
# Epoch 57/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.8608 - loss: 0.4829 - precision: 0.8809 - recall: 0.8314 - top_2_accuracy: 0.9618
# Epoch 57: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 444ms/step - accuracy: 0.8608 - loss: 0.4822 - precision: 0.8809 - recall: 0.8314 - top_2_accuracy: 0.9618 - val_accuracy: 0.9274 - val_loss: 0.2041 - val_precision: 0.9355 - val_recall: 0.9129 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 58/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.8593 - loss: 0.5168 - precision: 0.8845 - recall: 0.8398 - top_2_accuracy: 0.9409
# Epoch 58: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 437ms/step - accuracy: 0.8592 - loss: 0.5170 - precision: 0.8843 - recall: 0.8397 - top_2_accuracy: 0.9409 - val_accuracy: 0.9258 - val_loss: 0.2054 - val_precision: 0.9370 - val_recall: 0.9113 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 59/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step - accuracy: 0.8702 - loss: 0.4475 - precision: 0.8852 - recall: 0.8560 - top_2_accuracy: 0.9516
# Epoch 59: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 461ms/step - accuracy: 0.8702 - loss: 0.4475 - precision: 0.8852 - recall: 0.8560 - top_2_accuracy: 0.9517 - val_accuracy: 0.9258 - val_loss: 0.2069 - val_precision: 0.9354 - val_recall: 0.9113 - val_top_2_accuracy: 0.9855 - learning_rate: 1.0000e-07
# Epoch 60/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.8556 - loss: 0.5032 - precision: 0.8749 - recall: 0.8382 - top_2_accuracy: 0.9565
# Epoch 60: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 444ms/step - accuracy: 0.8557 - loss: 0.5030 - precision: 0.8750 - recall: 0.8383 - top_2_accuracy: 0.9565 - val_accuracy: 0.9258 - val_loss: 0.2074 - val_precision: 0.9339 - val_recall: 0.9113 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 61/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8839 - loss: 0.3931 - precision: 0.9029 - recall: 0.8630 - top_2_accuracy: 0.9575
# Epoch 61: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 437ms/step - accuracy: 0.8836 - loss: 0.3939 - precision: 0.9026 - recall: 0.8627 - top_2_accuracy: 0.9575 - val_accuracy: 0.9258 - val_loss: 0.2088 - val_precision: 0.9339 - val_recall: 0.9113 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 62/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.8821 - loss: 0.3842 - precision: 0.9006 - recall: 0.8722 - top_2_accuracy: 0.9569
# Epoch 62: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 438ms/step - accuracy: 0.8819 - loss: 0.3849 - precision: 0.9004 - recall: 0.8720 - top_2_accuracy: 0.9568 - val_accuracy: 0.9258 - val_loss: 0.2097 - val_precision: 0.9338 - val_recall: 0.9097 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 63/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.8661 - loss: 0.5120 - precision: 0.8788 - recall: 0.8485 - top_2_accuracy: 0.9533
# Epoch 63: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 436ms/step - accuracy: 0.8660 - loss: 0.5119 - precision: 0.8788 - recall: 0.8485 - top_2_accuracy: 0.9532 - val_accuracy: 0.9242 - val_loss: 0.2111 - val_precision: 0.9338 - val_recall: 0.9097 - val_top_2_accuracy: 0.9855 - learning_rate: 1.0000e-07
# Epoch 64/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.8790 - loss: 0.3830 - precision: 0.9001 - recall: 0.8642 - top_2_accuracy: 0.9602
# Epoch 64: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 436ms/step - accuracy: 0.8788 - loss: 0.3841 - precision: 0.8999 - recall: 0.8640 - top_2_accuracy: 0.9600 - val_accuracy: 0.9242 - val_loss: 0.2120 - val_precision: 0.9338 - val_recall: 0.9097 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 65/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.8751 - loss: 0.4515 - precision: 0.8917 - recall: 0.8602 - top_2_accuracy: 0.9553
# Epoch 65: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 443ms/step - accuracy: 0.8752 - loss: 0.4512 - precision: 0.8918 - recall: 0.8602 - top_2_accuracy: 0.9553 - val_accuracy: 0.9226 - val_loss: 0.2130 - val_precision: 0.9338 - val_recall: 0.9097 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 66/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 417ms/step - accuracy: 0.8650 - loss: 0.4119 - precision: 0.8844 - recall: 0.8483 - top_2_accuracy: 0.9640
# Epoch 66: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 447ms/step - accuracy: 0.8651 - loss: 0.4120 - precision: 0.8845 - recall: 0.8485 - top_2_accuracy: 0.9640 - val_accuracy: 0.9194 - val_loss: 0.2137 - val_precision: 0.9320 - val_recall: 0.9065 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 67/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step - accuracy: 0.8763 - loss: 0.4238 - precision: 0.8885 - recall: 0.8573 - top_2_accuracy: 0.9595
# Epoch 67: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 451ms/step - accuracy: 0.8764 - loss: 0.4241 - precision: 0.8886 - recall: 0.8573 - top_2_accuracy: 0.9595 - val_accuracy: 0.9177 - val_loss: 0.2143 - val_precision: 0.9303 - val_recall: 0.9048 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 68/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.8895 - loss: 0.3797 - precision: 0.9073 - recall: 0.8785 - top_2_accuracy: 0.9627
# Epoch 68: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 442ms/step - accuracy: 0.8895 - loss: 0.3796 - precision: 0.9073 - recall: 0.8784 - top_2_accuracy: 0.9627 - val_accuracy: 0.9161 - val_loss: 0.2149 - val_precision: 0.9303 - val_recall: 0.9048 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 69/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step - accuracy: 0.8665 - loss: 0.4782 - precision: 0.8818 - recall: 0.8507 - top_2_accuracy: 0.9589
# Epoch 69: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 449ms/step - accuracy: 0.8664 - loss: 0.4783 - precision: 0.8817 - recall: 0.8505 - top_2_accuracy: 0.9588 - val_accuracy: 0.9177 - val_loss: 0.2154 - val_precision: 0.9306 - val_recall: 0.9081 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 70/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.8512 - loss: 0.4897 - precision: 0.8721 - recall: 0.8381 - top_2_accuracy: 0.9484
# Epoch 70: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 448ms/step - accuracy: 0.8514 - loss: 0.4892 - precision: 0.8722 - recall: 0.8382 - top_2_accuracy: 0.9486 - val_accuracy: 0.9177 - val_loss: 0.2163 - val_precision: 0.9303 - val_recall: 0.9048 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 71/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.8640 - loss: 0.4270 - precision: 0.8781 - recall: 0.8425 - top_2_accuracy: 0.9606
# Epoch 71: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 443ms/step - accuracy: 0.8642 - loss: 0.4270 - precision: 0.8782 - recall: 0.8427 - top_2_accuracy: 0.9607 - val_accuracy: 0.9161 - val_loss: 0.2177 - val_precision: 0.9302 - val_recall: 0.9032 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 72/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.8768 - loss: 0.3619 - precision: 0.8962 - recall: 0.8576 - top_2_accuracy: 0.9612
# Epoch 72: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 443ms/step - accuracy: 0.8768 - loss: 0.3623 - precision: 0.8961 - recall: 0.8577 - top_2_accuracy: 0.9612 - val_accuracy: 0.9161 - val_loss: 0.2176 - val_precision: 0.9303 - val_recall: 0.9048 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 73/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.8706 - loss: 0.4415 - precision: 0.8874 - recall: 0.8567 - top_2_accuracy: 0.9664
# Epoch 73: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 440ms/step - accuracy: 0.8704 - loss: 0.4419 - precision: 0.8872 - recall: 0.8566 - top_2_accuracy: 0.9663 - val_accuracy: 0.9161 - val_loss: 0.2176 - val_precision: 0.9303 - val_recall: 0.9048 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 74/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step - accuracy: 0.8804 - loss: 0.4037 - precision: 0.8947 - recall: 0.8492 - top_2_accuracy: 0.9645
# Epoch 74: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 437ms/step - accuracy: 0.8802 - loss: 0.4041 - precision: 0.8946 - recall: 0.8492 - top_2_accuracy: 0.9645 - val_accuracy: 0.9177 - val_loss: 0.2176 - val_precision: 0.9305 - val_recall: 0.9065 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 75/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 402ms/step - accuracy: 0.8770 - loss: 0.4197 - precision: 0.8883 - recall: 0.8552 - top_2_accuracy: 0.9575
# Epoch 75: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 429ms/step - accuracy: 0.8769 - loss: 0.4204 - precision: 0.8883 - recall: 0.8551 - top_2_accuracy: 0.9575 - val_accuracy: 0.9177 - val_loss: 0.2182 - val_precision: 0.9305 - val_recall: 0.9065 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 76/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8742 - loss: 0.3865 - precision: 0.8955 - recall: 0.8625 - top_2_accuracy: 0.9631
# Epoch 76: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 439ms/step - accuracy: 0.8743 - loss: 0.3869 - precision: 0.8955 - recall: 0.8625 - top_2_accuracy: 0.9631 - val_accuracy: 0.9177 - val_loss: 0.2180 - val_precision: 0.9305 - val_recall: 0.9065 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 77/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 437ms/step - accuracy: 0.8723 - loss: 0.4604 - precision: 0.8903 - recall: 0.8561 - top_2_accuracy: 0.9514
# Epoch 77: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 465ms/step - accuracy: 0.8723 - loss: 0.4600 - precision: 0.8903 - recall: 0.8560 - top_2_accuracy: 0.9516 - val_accuracy: 0.9161 - val_loss: 0.2183 - val_precision: 0.9305 - val_recall: 0.9065 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 78/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.8827 - loss: 0.4000 - precision: 0.8998 - recall: 0.8624 - top_2_accuracy: 0.9693
# Epoch 78: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 431ms/step - accuracy: 0.8827 - loss: 0.4007 - precision: 0.8998 - recall: 0.8623 - top_2_accuracy: 0.9693 - val_accuracy: 0.9177 - val_loss: 0.2185 - val_precision: 0.9319 - val_recall: 0.9048 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 79/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8538 - loss: 0.4442 - precision: 0.8794 - recall: 0.8328 - top_2_accuracy: 0.9614
# Epoch 79: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 440ms/step - accuracy: 0.8539 - loss: 0.4438 - precision: 0.8796 - recall: 0.8330 - top_2_accuracy: 0.9613 - val_accuracy: 0.9161 - val_loss: 0.2195 - val_precision: 0.9319 - val_recall: 0.9048 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 80/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8976 - loss: 0.3912 - precision: 0.9140 - recall: 0.8785 - top_2_accuracy: 0.9548
# Epoch 80: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 433ms/step - accuracy: 0.8973 - loss: 0.3916 - precision: 0.9137 - recall: 0.8782 - top_2_accuracy: 0.9548 - val_accuracy: 0.9161 - val_loss: 0.2195 - val_precision: 0.9320 - val_recall: 0.9065 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 81/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8729 - loss: 0.3825 - precision: 0.8906 - recall: 0.8582 - top_2_accuracy: 0.9614
# Epoch 81: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 437ms/step - accuracy: 0.8730 - loss: 0.3823 - precision: 0.8907 - recall: 0.8582 - top_2_accuracy: 0.9614 - val_accuracy: 0.9161 - val_loss: 0.2206 - val_precision: 0.9319 - val_recall: 0.9048 - val_top_2_accuracy: 0.9823 - learning_rate: 1.0000e-07
# Epoch 82/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8761 - loss: 0.4470 - precision: 0.8945 - recall: 0.8597 - top_2_accuracy: 0.9608
# Epoch 82: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 438ms/step - accuracy: 0.8759 - loss: 0.4471 - precision: 0.8944 - recall: 0.8595 - top_2_accuracy: 0.9608 - val_accuracy: 0.9177 - val_loss: 0.2215 - val_precision: 0.9318 - val_recall: 0.9032 - val_top_2_accuracy: 0.9823 - learning_rate: 1.0000e-07
# Epoch 83/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8948 - loss: 0.3557 - precision: 0.9124 - recall: 0.8838 - top_2_accuracy: 0.9664
# Epoch 83: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 440ms/step - accuracy: 0.8946 - loss: 0.3564 - precision: 0.9122 - recall: 0.8836 - top_2_accuracy: 0.9664 - val_accuracy: 0.9177 - val_loss: 0.2214 - val_precision: 0.9319 - val_recall: 0.9048 - val_top_2_accuracy: 0.9823 - learning_rate: 1.0000e-07
# Epoch 84/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.8828 - loss: 0.3911 - precision: 0.8973 - recall: 0.8680 - top_2_accuracy: 0.9594
# Epoch 84: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 443ms/step - accuracy: 0.8829 - loss: 0.3911 - precision: 0.8973 - recall: 0.8680 - top_2_accuracy: 0.9595 - val_accuracy: 0.9177 - val_loss: 0.2214 - val_precision: 0.9318 - val_recall: 0.9032 - val_top_2_accuracy: 0.9823 - learning_rate: 1.0000e-07
# Epoch 85/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step - accuracy: 0.8876 - loss: 0.3770 - precision: 0.9050 - recall: 0.8730 - top_2_accuracy: 0.9695
# Epoch 85: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 467ms/step - accuracy: 0.8874 - loss: 0.3774 - precision: 0.9048 - recall: 0.8728 - top_2_accuracy: 0.9694 - val_accuracy: 0.9161 - val_loss: 0.2205 - val_precision: 0.9318 - val_recall: 0.9032 - val_top_2_accuracy: 0.9823 - learning_rate: 1.0000e-07
# Epoch 86/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step - accuracy: 0.8904 - loss: 0.3496 - precision: 0.9155 - recall: 0.8735 - top_2_accuracy: 0.9651
# Epoch 86: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 26s 496ms/step - accuracy: 0.8905 - loss: 0.3498 - precision: 0.9154 - recall: 0.8735 - top_2_accuracy: 0.9651 - val_accuracy: 0.9161 - val_loss: 0.2203 - val_precision: 0.9318 - val_recall: 0.9032 - val_top_2_accuracy: 0.9823 - learning_rate: 1.0000e-07
# Epoch 87/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step - accuracy: 0.8874 - loss: 0.3615 - precision: 0.9094 - recall: 0.8728 - top_2_accuracy: 0.9562
# Epoch 87: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 25s 476ms/step - accuracy: 0.8873 - loss: 0.3624 - precision: 0.9092 - recall: 0.8726 - top_2_accuracy: 0.9561 - val_accuracy: 0.9161 - val_loss: 0.2205 - val_precision: 0.9319 - val_recall: 0.9048 - val_top_2_accuracy: 0.9823 - learning_rate: 1.0000e-07
# Epoch 88/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8897 - loss: 0.3564 - precision: 0.9086 - recall: 0.8737 - top_2_accuracy: 0.9591
# Epoch 88: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 437ms/step - accuracy: 0.8897 - loss: 0.3569 - precision: 0.9086 - recall: 0.8738 - top_2_accuracy: 0.9592 - val_accuracy: 0.9161 - val_loss: 0.2203 - val_precision: 0.9318 - val_recall: 0.9032 - val_top_2_accuracy: 0.9823 - learning_rate: 1.0000e-07
# Epoch 89/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.8872 - loss: 0.3546 - precision: 0.9029 - recall: 0.8661 - top_2_accuracy: 0.9631
# Epoch 89: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 446ms/step - accuracy: 0.8872 - loss: 0.3551 - precision: 0.9029 - recall: 0.8660 - top_2_accuracy: 0.9632 - val_accuracy: 0.9177 - val_loss: 0.2204 - val_precision: 0.9334 - val_recall: 0.9048 - val_top_2_accuracy: 0.9823 - learning_rate: 1.0000e-07
# Epoch 90/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.8635 - loss: 0.4787 - precision: 0.8817 - recall: 0.8476 - top_2_accuracy: 0.9538
# Epoch 90: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 444ms/step - accuracy: 0.8637 - loss: 0.4790 - precision: 0.8818 - recall: 0.8477 - top_2_accuracy: 0.9538 - val_accuracy: 0.9177 - val_loss: 0.2208 - val_precision: 0.9319 - val_recall: 0.9048 - val_top_2_accuracy: 0.9823 - learning_rate: 1.0000e-07
# Epoch 91/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.8743 - loss: 0.4044 - precision: 0.8926 - recall: 0.8597 - top_2_accuracy: 0.9635
# Epoch 91: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 442ms/step - accuracy: 0.8744 - loss: 0.4044 - precision: 0.8926 - recall: 0.8597 - top_2_accuracy: 0.9635 - val_accuracy: 0.9194 - val_loss: 0.2199 - val_precision: 0.9320 - val_recall: 0.9065 - val_top_2_accuracy: 0.9823 - learning_rate: 1.0000e-07
# Epoch 92/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8780 - loss: 0.3870 - precision: 0.8957 - recall: 0.8632 - top_2_accuracy: 0.9686
# Epoch 92: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 443ms/step - accuracy: 0.8779 - loss: 0.3875 - precision: 0.8956 - recall: 0.8631 - top_2_accuracy: 0.9684 - val_accuracy: 0.9194 - val_loss: 0.2193 - val_precision: 0.9319 - val_recall: 0.9048 - val_top_2_accuracy: 0.9823 - learning_rate: 1.0000e-07
# Epoch 93/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8864 - loss: 0.4107 - precision: 0.8991 - recall: 0.8698 - top_2_accuracy: 0.9673
# Epoch 93: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 438ms/step - accuracy: 0.8861 - loss: 0.4112 - precision: 0.8989 - recall: 0.8695 - top_2_accuracy: 0.9672 - val_accuracy: 0.9194 - val_loss: 0.2188 - val_precision: 0.9317 - val_recall: 0.9016 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 94/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.8847 - loss: 0.4344 - precision: 0.9046 - recall: 0.8670 - top_2_accuracy: 0.9666
# Epoch 94: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 440ms/step - accuracy: 0.8846 - loss: 0.4346 - precision: 0.9045 - recall: 0.8669 - top_2_accuracy: 0.9665 - val_accuracy: 0.9194 - val_loss: 0.2192 - val_precision: 0.9333 - val_recall: 0.9032 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 95/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.8633 - loss: 0.4786 - precision: 0.8810 - recall: 0.8458 - top_2_accuracy: 0.9497
# Epoch 95: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 461ms/step - accuracy: 0.8631 - loss: 0.4786 - precision: 0.8809 - recall: 0.8457 - top_2_accuracy: 0.9498 - val_accuracy: 0.9194 - val_loss: 0.2187 - val_precision: 0.9332 - val_recall: 0.9016 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 96/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.8775 - loss: 0.3628 - precision: 0.8956 - recall: 0.8617 - top_2_accuracy: 0.9711
# Epoch 96: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 439ms/step - accuracy: 0.8774 - loss: 0.3637 - precision: 0.8955 - recall: 0.8616 - top_2_accuracy: 0.9711 - val_accuracy: 0.9194 - val_loss: 0.2176 - val_precision: 0.9350 - val_recall: 0.9048 - val_top_2_accuracy: 0.9823 - learning_rate: 1.0000e-07
# Epoch 97/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.8599 - loss: 0.5246 - precision: 0.8786 - recall: 0.8411 - top_2_accuracy: 0.9445
# Epoch 97: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 441ms/step - accuracy: 0.8603 - loss: 0.5228 - precision: 0.8790 - recall: 0.8415 - top_2_accuracy: 0.9447 - val_accuracy: 0.9194 - val_loss: 0.2176 - val_precision: 0.9350 - val_recall: 0.9048 - val_top_2_accuracy: 0.9823 - learning_rate: 1.0000e-07
# Epoch 98/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.8774 - loss: 0.4446 - precision: 0.8921 - recall: 0.8541 - top_2_accuracy: 0.9558
# Epoch 98: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 437ms/step - accuracy: 0.8775 - loss: 0.4443 - precision: 0.8922 - recall: 0.8542 - top_2_accuracy: 0.9558 - val_accuracy: 0.9194 - val_loss: 0.2180 - val_precision: 0.9333 - val_recall: 0.9032 - val_top_2_accuracy: 0.9839 - learning_rate: 1.0000e-07
# Epoch 99/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.8735 - loss: 0.4248 - precision: 0.8939 - recall: 0.8610 - top_2_accuracy: 0.9596
# Epoch 99: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 441ms/step - accuracy: 0.8736 - loss: 0.4248 - precision: 0.8940 - recall: 0.8611 - top_2_accuracy: 0.9596 - val_accuracy: 0.9194 - val_loss: 0.2175 - val_precision: 0.9318 - val_recall: 0.9032 - val_top_2_accuracy: 0.9823 - learning_rate: 1.0000e-07
# Epoch 100/300
# ...
# Epoch 269: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 435ms/step - accuracy: 0.8835 - loss: 0.4031 - precision: 0.8991 - recall: 0.8750 - top_2_accuracy: 0.9649 - val_accuracy: 0.9371 - val_loss: 0.1677 - val_precision: 0.9502 - val_recall: 0.9242 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 270/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.9079 - loss: 0.2906 - precision: 0.9172 - recall: 0.8891 - top_2_accuracy: 0.9719
# Epoch 270: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 438ms/step - accuracy: 0.9080 - loss: 0.2905 - precision: 0.9173 - recall: 0.8891 - top_2_accuracy: 0.9720 - val_accuracy: 0.9371 - val_loss: 0.1675 - val_precision: 0.9488 - val_recall: 0.9258 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 271/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step - accuracy: 0.9081 - loss: 0.3295 - precision: 0.9180 - recall: 0.8858 - top_2_accuracy: 0.9725
# Epoch 271: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 429ms/step - accuracy: 0.9082 - loss: 0.3295 - precision: 0.9181 - recall: 0.8858 - top_2_accuracy: 0.9725 - val_accuracy: 0.9371 - val_loss: 0.1673 - val_precision: 0.9503 - val_recall: 0.9258 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 272/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.9090 - loss: 0.3269 - precision: 0.9214 - recall: 0.8968 - top_2_accuracy: 0.9676
# Epoch 272: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 433ms/step - accuracy: 0.9089 - loss: 0.3270 - precision: 0.9213 - recall: 0.8967 - top_2_accuracy: 0.9676 - val_accuracy: 0.9371 - val_loss: 0.1668 - val_precision: 0.9502 - val_recall: 0.9242 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 273/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.8806 - loss: 0.3407 - precision: 0.9008 - recall: 0.8683 - top_2_accuracy: 0.9715
# Epoch 273: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 431ms/step - accuracy: 0.8807 - loss: 0.3407 - precision: 0.9009 - recall: 0.8685 - top_2_accuracy: 0.9715 - val_accuracy: 0.9387 - val_loss: 0.1663 - val_precision: 0.9487 - val_recall: 0.9242 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 274/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step - accuracy: 0.9045 - loss: 0.2984 - precision: 0.9237 - recall: 0.8902 - top_2_accuracy: 0.9768
# Epoch 274: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 430ms/step - accuracy: 0.9044 - loss: 0.2987 - precision: 0.9236 - recall: 0.8902 - top_2_accuracy: 0.9767 - val_accuracy: 0.9387 - val_loss: 0.1658 - val_precision: 0.9488 - val_recall: 0.9274 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 275/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.8867 - loss: 0.3768 - precision: 0.9121 - recall: 0.8711 - top_2_accuracy: 0.9538
# Epoch 275: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 436ms/step - accuracy: 0.8870 - loss: 0.3760 - precision: 0.9123 - recall: 0.8714 - top_2_accuracy: 0.9540 - val_accuracy: 0.9387 - val_loss: 0.1657 - val_precision: 0.9504 - val_recall: 0.9274 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 276/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8960 - loss: 0.3632 - precision: 0.9130 - recall: 0.8866 - top_2_accuracy: 0.9768
# Epoch 276: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 434ms/step - accuracy: 0.8962 - loss: 0.3625 - precision: 0.9131 - recall: 0.8867 - top_2_accuracy: 0.9767 - val_accuracy: 0.9387 - val_loss: 0.1655 - val_precision: 0.9488 - val_recall: 0.9274 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 277/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.8945 - loss: 0.3348 - precision: 0.9071 - recall: 0.8849 - top_2_accuracy: 0.9733
# Epoch 277: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 435ms/step - accuracy: 0.8945 - loss: 0.3351 - precision: 0.9071 - recall: 0.8848 - top_2_accuracy: 0.9732 - val_accuracy: 0.9387 - val_loss: 0.1649 - val_precision: 0.9487 - val_recall: 0.9242 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 278/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step - accuracy: 0.8950 - loss: 0.3426 - precision: 0.9117 - recall: 0.8787 - top_2_accuracy: 0.9733
# Epoch 278: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 22s 430ms/step - accuracy: 0.8952 - loss: 0.3422 - precision: 0.9119 - recall: 0.8788 - top_2_accuracy: 0.9732 - val_accuracy: 0.9387 - val_loss: 0.1649 - val_precision: 0.9504 - val_recall: 0.9274 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 279/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.8971 - loss: 0.3160 - precision: 0.9153 - recall: 0.8861 - top_2_accuracy: 0.9740
# Epoch 279: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 439ms/step - accuracy: 0.8971 - loss: 0.3157 - precision: 0.9153 - recall: 0.8862 - top_2_accuracy: 0.9741 - val_accuracy: 0.9387 - val_loss: 0.1649 - val_precision: 0.9504 - val_recall: 0.9274 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 280/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.8997 - loss: 0.3126 - precision: 0.9166 - recall: 0.8864 - top_2_accuracy: 0.9770
# Epoch 280: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 441ms/step - accuracy: 0.8997 - loss: 0.3128 - precision: 0.9166 - recall: 0.8863 - top_2_accuracy: 0.9770 - val_accuracy: 0.9387 - val_loss: 0.1650 - val_precision: 0.9504 - val_recall: 0.9274 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 281/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9032 - loss: 0.3200 - precision: 0.9173 - recall: 0.8896 - top_2_accuracy: 0.9727
# Epoch 281: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 433ms/step - accuracy: 0.9032 - loss: 0.3203 - precision: 0.9173 - recall: 0.8896 - top_2_accuracy: 0.9727 - val_accuracy: 0.9387 - val_loss: 0.1648 - val_precision: 0.9502 - val_recall: 0.9242 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 282/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.9019 - loss: 0.3415 - precision: 0.9146 - recall: 0.8851 - top_2_accuracy: 0.9713
# Epoch 282: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 444ms/step - accuracy: 0.9018 - loss: 0.3415 - precision: 0.9146 - recall: 0.8850 - top_2_accuracy: 0.9713 - val_accuracy: 0.9387 - val_loss: 0.1637 - val_precision: 0.9504 - val_recall: 0.9274 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 283/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.8885 - loss: 0.3965 - precision: 0.9010 - recall: 0.8719 - top_2_accuracy: 0.9734
# Epoch 283: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 24s 455ms/step - accuracy: 0.8886 - loss: 0.3957 - precision: 0.9011 - recall: 0.8721 - top_2_accuracy: 0.9735 - val_accuracy: 0.9387 - val_loss: 0.1637 - val_precision: 0.9505 - val_recall: 0.9290 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 284/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.8901 - loss: 0.3443 - precision: 0.9115 - recall: 0.8786 - top_2_accuracy: 0.9726
# Epoch 284: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 441ms/step - accuracy: 0.8902 - loss: 0.3438 - precision: 0.9116 - recall: 0.8787 - top_2_accuracy: 0.9726 - val_accuracy: 0.9387 - val_loss: 0.1633 - val_precision: 0.9488 - val_recall: 0.9274 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 285/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.8978 - loss: 0.3417 - precision: 0.9151 - recall: 0.8774 - top_2_accuracy: 0.9666
# Epoch 285: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 438ms/step - accuracy: 0.8979 - loss: 0.3411 - precision: 0.9152 - recall: 0.8774 - top_2_accuracy: 0.9667 - val_accuracy: 0.9387 - val_loss: 0.1627 - val_precision: 0.9504 - val_recall: 0.9274 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 286/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.9103 - loss: 0.2889 - precision: 0.9225 - recall: 0.8957 - top_2_accuracy: 0.9737
# Epoch 286: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 438ms/step - accuracy: 0.9103 - loss: 0.2894 - precision: 0.9224 - recall: 0.8957 - top_2_accuracy: 0.9737 - val_accuracy: 0.9387 - val_loss: 0.1627 - val_precision: 0.9503 - val_recall: 0.9258 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 287/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step - accuracy: 0.9010 - loss: 0.3257 - precision: 0.9154 - recall: 0.8745 - top_2_accuracy: 0.9719
# Epoch 287: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 445ms/step - accuracy: 0.9009 - loss: 0.3258 - precision: 0.9153 - recall: 0.8746 - top_2_accuracy: 0.9719 - val_accuracy: 0.9387 - val_loss: 0.1625 - val_precision: 0.9502 - val_recall: 0.9242 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 288/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 412ms/step - accuracy: 0.9046 - loss: 0.2927 - precision: 0.9247 - recall: 0.8925 - top_2_accuracy: 0.9740
# Epoch 288: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 441ms/step - accuracy: 0.9046 - loss: 0.2931 - precision: 0.9246 - recall: 0.8924 - top_2_accuracy: 0.9740 - val_accuracy: 0.9387 - val_loss: 0.1624 - val_precision: 0.9502 - val_recall: 0.9242 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 289/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.9100 - loss: 0.2926 - precision: 0.9211 - recall: 0.8934 - top_2_accuracy: 0.9792
# Epoch 289: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 443ms/step - accuracy: 0.9095 - loss: 0.2939 - precision: 0.9207 - recall: 0.8930 - top_2_accuracy: 0.9791 - val_accuracy: 0.9387 - val_loss: 0.1619 - val_precision: 0.9488 - val_recall: 0.9258 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 290/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.9103 - loss: 0.3223 - precision: 0.9223 - recall: 0.8978 - top_2_accuracy: 0.9651
# Epoch 290: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 443ms/step - accuracy: 0.9103 - loss: 0.3223 - precision: 0.9223 - recall: 0.8978 - top_2_accuracy: 0.9652 - val_accuracy: 0.9387 - val_loss: 0.1617 - val_precision: 0.9503 - val_recall: 0.9258 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 291/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.9207 - loss: 0.2824 - precision: 0.9357 - recall: 0.9103 - top_2_accuracy: 0.9747
# Epoch 291: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 445ms/step - accuracy: 0.9205 - loss: 0.2828 - precision: 0.9356 - recall: 0.9100 - top_2_accuracy: 0.9746 - val_accuracy: 0.9387 - val_loss: 0.1614 - val_precision: 0.9506 - val_recall: 0.9306 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 292/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9180 - loss: 0.2657 - precision: 0.9320 - recall: 0.9037 - top_2_accuracy: 0.9841
# Epoch 292: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 432ms/step - accuracy: 0.9180 - loss: 0.2657 - precision: 0.9319 - recall: 0.9036 - top_2_accuracy: 0.9840 - val_accuracy: 0.9387 - val_loss: 0.1614 - val_precision: 0.9504 - val_recall: 0.9274 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 293/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.9055 - loss: 0.3152 - precision: 0.9171 - recall: 0.8960 - top_2_accuracy: 0.9659
# Epoch 293: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 435ms/step - accuracy: 0.9057 - loss: 0.3142 - precision: 0.9173 - recall: 0.8962 - top_2_accuracy: 0.9661 - val_accuracy: 0.9387 - val_loss: 0.1610 - val_precision: 0.9505 - val_recall: 0.9290 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 294/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.8921 - loss: 0.3182 - precision: 0.9117 - recall: 0.8793 - top_2_accuracy: 0.9748
# Epoch 294: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 435ms/step - accuracy: 0.8923 - loss: 0.3179 - precision: 0.9119 - recall: 0.8795 - top_2_accuracy: 0.9748 - val_accuracy: 0.9403 - val_loss: 0.1604 - val_precision: 0.9489 - val_recall: 0.9290 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 295/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.9048 - loss: 0.3344 - precision: 0.9146 - recall: 0.8860 - top_2_accuracy: 0.9777
# Epoch 295: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 447ms/step - accuracy: 0.9046 - loss: 0.3342 - precision: 0.9146 - recall: 0.8860 - top_2_accuracy: 0.9776 - val_accuracy: 0.9387 - val_loss: 0.1599 - val_precision: 0.9474 - val_recall: 0.9290 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 296/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step - accuracy: 0.8981 - loss: 0.3421 - precision: 0.9148 - recall: 0.8868 - top_2_accuracy: 0.9658
# Epoch 296: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 445ms/step - accuracy: 0.8982 - loss: 0.3420 - precision: 0.9148 - recall: 0.8869 - top_2_accuracy: 0.9659 - val_accuracy: 0.9387 - val_loss: 0.1603 - val_precision: 0.9490 - val_recall: 0.9306 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 297/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step - accuracy: 0.9000 - loss: 0.3269 - precision: 0.9167 - recall: 0.8811 - top_2_accuracy: 0.9723
# Epoch 297: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 443ms/step - accuracy: 0.9001 - loss: 0.3265 - precision: 0.9167 - recall: 0.8812 - top_2_accuracy: 0.9724 - val_accuracy: 0.9403 - val_loss: 0.1601 - val_precision: 0.9506 - val_recall: 0.9306 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 298/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step - accuracy: 0.9131 - loss: 0.2512 - precision: 0.9304 - recall: 0.9045 - top_2_accuracy: 0.9766
# Epoch 298: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 437ms/step - accuracy: 0.9129 - loss: 0.2522 - precision: 0.9302 - recall: 0.9042 - top_2_accuracy: 0.9765 - val_accuracy: 0.9403 - val_loss: 0.1596 - val_precision: 0.9505 - val_recall: 0.9290 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 299/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step - accuracy: 0.9085 - loss: 0.2822 - precision: 0.9244 - recall: 0.8931 - top_2_accuracy: 0.9730
# Epoch 299: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 435ms/step - accuracy: 0.9085 - loss: 0.2827 - precision: 0.9244 - recall: 0.8931 - top_2_accuracy: 0.9730 - val_accuracy: 0.9403 - val_loss: 0.1591 - val_precision: 0.9472 - val_recall: 0.9258 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Epoch 300/300
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step - accuracy: 0.9037 - loss: 0.3476 - precision: 0.9198 - recall: 0.8795 - top_2_accuracy: 0.9684
# Epoch 300: val_loss did not improve from 0.02076
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 23s 436ms/step - accuracy: 0.9037 - loss: 0.3474 - precision: 0.9197 - recall: 0.8796 - top_2_accuracy: 0.9684 - val_accuracy: 0.9403 - val_loss: 0.1594 - val_precision: 0.9489 - val_recall: 0.9290 - val_top_2_accuracy: 0.9887 - learning_rate: 1.0000e-07
# Restoring model weights from the end of the best epoch: 1.
#
# PHASE-02: Training Completed Successfully!!!!
#
# ============================================================
# Final Train Loss: [0.335613876581192]
# Best Train Loss: [0.26471665501594543]
# Final Train Accuracy: [0.9042682647705078]
# Best Train Accuracy: [0.9164634346961975]
# ============================================================
# Final Validation Loss: [0.15939560532569885]
# Best Validation Loss: [0.020756451413035393]
# Final Validation Accuracy: [0.9403225779533386]
# Best Validation Accuracy: [0.9935483932495117]
# ============================================================

# %% [markdown]
# #### **Check For Overfitting Or Underfitting :**

# %%
best_train_acc = max(history_fine_tune.history['accuracy'])
best_val_acc = max(history_fine_tune.history['val_accuracy'])
dif = best_train_acc - best_val_acc

if dif > 0.1:
    print(f"Warning: Large gap [{dif:.3f}] between train and validation accuracy suggests overfitting!!!.")
elif dif < -0.1:
    print(f"Warning: Large gap [{dif:.3f}] between train and validation accuracy suggests underfitting!!!.")
else:
    print(f"Good Fit: Gap between train and validation accuracy is [{dif:.3f}]s.")
# Out:
# Good Fit: Gap between train and validation accuracy is [-0.077]s.

# %% [markdown]
# # **Plot Training History :**

# %%
def training_history_plot(history_frozen, history_fine_tune, plot_save_path, save_plot_name):
    
    plt.style.use('seaborn-v0_8')
    fig, axes = plt.subplots(1 , 2, figsize=(15,5))
    
    frozen_epochs = len(history_frozen.history['loss'])
    epochs = range(1, frozen_epochs + len(history_fine_tune.history['loss']) + 1)
        
    train_loss =  history_frozen.history['loss'] + history_fine_tune.history['loss']
    val_loss =  history_frozen.history['val_loss'] + history_fine_tune.history['val_loss']
    train_acc =  history_frozen.history['accuracy'] + history_fine_tune.history['accuracy']
    val_acc =  history_frozen.history['val_accuracy'] + history_fine_tune.history['val_accuracy']
        
    for ax in axes.flat:
        ax.axvline(x=frozen_epochs, color='r', linestyle='--', alpha=0.7, label='Fine-Tuning-Starts')
        
    # Plot loss
    axes[0].plot(epochs, train_loss, 'b-', label='Training Loss', linewidth=2)
    axes[0].plot(epochs, val_loss, 'r-', label='Validation Loss', linewidth=2)
    axes[0].set_title('Model Loss', fontsize=15, fontweight='bold')
    axes[0].set_xlabel('Epoch')
    axes[0].set_ylabel('Loss') 
    axes[0].legend()
    axes[0].grid(True, alpha=0.3)
    
    # Plot accuracy
    axes[1].plot(epochs, train_acc, 'b-', label='Training Accuracy', linewidth=2)
    axes[1].plot(epochs, val_acc, 'r-', label='Validation Accuracy', linewidth=2)
    axes[1].set_title('Model Accuracy', fontsize=15, fontweight='bold')
    axes[1].set_xlabel('Epoch')
    axes[1].set_ylabel('Accuracy') 
    axes[1].legend()
    axes[1].grid(True, alpha=0.3)
    
    plt.tight_layout()
    plt.savefig(os.path.join(plot_save_path, save_plot_name), dpi=300, bbox_inches='tight')
    plt.show()

# %%
training_history_plot(history_frozen=history_frozen,
                      history_fine_tune=history_fine_tune,
                      plot_save_path='/kaggle/working/',
                      save_plot_name='frozen_and_fine_tune_traning_plot.png')

# %% [markdown]
# # **Model Evaluation :**

# %%
def evaluate_model_with_visualization(model, test_gen, eval_results_save_path):
    
    # Reset generator to start from beginning
    test_gen.reset()
    
    predictions = model.predict(test_gen, verbose=1)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = test_gen.classes
    # Get class labels sorted by index  
    class_labels = [key for key, value in sorted(test_gen.class_indices.items(), key = lambda item: item[1])]
    
    # Plot or visualization "Confusion Matrix"
    con_mat = confusion_matrix(true_classes,  predicted_classes)
    plt.figure(figsize=(15,10))
    sns.heatmap(con_mat, annot=True, fmt='d', cmap='Reds', xticklabels=class_labels, yticklabels=class_labels, cbar_kws={'label': 'count'})
    plt.title('Confusion Matrix For Skin Disease Classification', fontsize=15, fontweight='bold')
    plt.ylabel('True Label', fontsize=12, fontweight='bold')
    plt.xlabel('Predicted Label', fontsize=12, fontweight='bold')
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()
    plt.savefig(os.path.join(eval_results_save_path, 'confusion_matrix.png'), dpi=300, bbox_inches='tight')
    plt.show()
    
    # Classification report
    cl_report = classification_report(true_classes, predicted_classes, target_names=class_labels, output_dict=True)
    print("\n" + "="*60)
    print("Classification Report")
    print("="*60)
    print(classification_report(true_classes, predicted_classes, target_names=class_labels))
    
    # Plot or visualiztion Per class metrics
    met_df = []
    for i, class_name in enumerate(class_labels):
        precision = cl_report[class_name]['precision']
        recall = cl_report[class_name]['recall']
        f1_score = cl_report[class_name]['f1-score']
        support = cl_report[class_name]['support']
        met_df.append({'Class': class_name,
                       'Precision': precision,
                       'Recall': recall, 
                       'F1-Score': f1_score,
                       'Support': support})
        
    fig, axes = plt.subplots(1,3, figsize=(15,5))
    
    classes = [m['Class'] for m in  met_df ] 
    precision_scores = [m['Precision'] for m in  met_df ] 
    recall_scores = [m['Recall'] for m in  met_df ]
    f1_scores = [m['F1-Score'] for m in  met_df ]
    
    # For precision
    axes[0].bar(classes, precision_scores, color='skyblue', alpha=0.7)
    axes[0].set_title('Precision By Class', fontweight='bold')
    axes[0].set_ylim(0,1)
    axes[0].tick_params(axis='x', rotation=45)    
    
    # For recall    
    axes[1].bar(classes, recall_scores, color='blue', alpha=0.7)
    axes[1].set_title('Recall By Class', fontweight='bold')
    axes[1].set_ylim(0,1)
    axes[1].tick_params(axis='x', rotation=45) 
    
    # For f1 score   
    axes[2].bar(classes, f1_scores, color='lightgreen', alpha=0.7)
    axes[2].set_title('F1-Score By Class', fontweight='bold')
    axes[2].set_ylim(0,1)
    axes[2].tick_params(axis='x', rotation=45) 
    
    plt.tight_layout()
    plt.savefig(os.path.join(eval_results_save_path, 'class_metrics.png'), dpi=300, bbox_inches='tight')
    plt.show() 
    
    return cl_report, con_mat

# %% [markdown]
# #### **Plot Sample Predictions With True And Predicted Labels :**

# %%
def plot_prediction_samples(model, test_gen, batch_images, samples_results_save_path, num_samples, no_subplot_x_axes, no_subplot_y_axes):
    
    # Reset generator to start from beginning
    test_gen.reset()
    
    # Get a batch of test images
    batch_images, batch_labels = next(test_gen)
    predictions = model.predict(batch_images)  
    # Get class labels sorted by index   
    class_labels = [key for key, value in sorted(test_gen.class_indices.items(), key = lambda item: item[1])]
    
    
    # Calculate grid size based on num_samples if not specified
    total_subplots = no_subplot_x_axes * no_subplot_y_axes
    if num_samples > total_subplots:
        print(f"Warning: num_samples [{num_samples}] exceeds subplot grid size [{total_subplots}]. Using [{total_subplots}] samples.")
        num_samples = total_subplots
    
    # Plot samples
    fig, axes = plt.subplots(no_subplot_x_axes, no_subplot_y_axes, figsize=(12,12))
    
    # Handle case where we have only one subplot
    if no_subplot_x_axes == 1 and no_subplot_y_axes ==1:
        axes = [axes]
    else:
        axes = axes.ravel()
            
    for i in range(min(num_samples, len(batch_images))):
     
        img = batch_images[i]
        
        # Handle different image formats
        if img.shape[-1] == 1: # for Grayscale image
            img = img.squeeze()
            cmap = 'gray'
        else:
            cmap = None
    
        # Normalize image to [0,1] range for display
        img_min, img_max = img.min(), img.max()
        if img_max > img_min: # Avoid division by zero
            img = (img - img_min) / (img_max - img_min)   

        true_class_idx = np.argmax(batch_labels[i])
        pred_class_idx = np.argmax(predictions[i])
        confidence = predictions[i][pred_class_idx]
        
        true_label = class_labels[true_class_idx]
        pred_label = class_labels[pred_class_idx]
        
        
        color = 'green' if true_class_idx == pred_class_idx else 'red'

        axes[i].imshow(img, cmap=cmap)
        axes[i].set_title(f'True: {true_label}\nPred: {pred_label}\nConf: {confidence:.3f}', color=color, fontsize=10, fontweight='bold')
        axes[i].axis('off')
        
    # Hide unused subplots
    for i in range(num_samples, len(axes)):
        axes[i].axis('off')
        axes[i].set_visible(False)
            
    # Adjust layout and save
    plt.tight_layout()
        
    plt.tight_layout()
    plt.savefig(os.path.join(samples_results_save_path, 'prediction_samples.png'), dpi=300, bbox_inches='tight')
    plt.show()
    
    # Return some metrics for analysis
    correct_predictions = sum(1 for i in range(min(num_samples, len(batch_images))) if np.argmax(batch_labels[i]) == np.argmax(predictions[i]))
    accuracy = correct_predictions / min(num_samples, len(batch_images))
    print(f"Accuracy on displayed samples: [{accuracy:.3f}] [{correct_predictions}/{min(num_samples, len(batch_images))}]")
    
    return accuracy

# %% [markdown]
# #### **Load Best Model And Evaluate :**

# %%
def load_best_model_and_evaluate(new_model, final_model_save_path, test_gen, eval_results_save_path, 
                                 batch_images, samples_results_save_path, num_samples, 
                                 no_subplot_x_axes, no_subplot_y_axes):
    
    # Load best model 
    try:
        new_model.load_weights(final_model_save_path)
        model = new_model
        print("Best Model Load successfully.")
    except Exception as e:
        print(f"Model can't find or error occured during load the model: {e}")
        return None
      
    print("Model Evaluation Has Been Started...........................")
    print("="*60)    
    test_results = model.evaluate(test_gen, return_dict=True, verbose=1)
    
    print("\nTest Results:")
    for metric, value in test_results.items():
        print(f"{metric.capitalize()}: {value:.4f}")
    
    # Calculate macro and weighted F1-scores
    detailed_report, cm = evaluate_model_with_visualization(model, test_gen, eval_results_save_path) 
    # Calculate final metrics 
    macro_f1 =  detailed_report['macro avg']['f1-score']
    weighted_f1 = detailed_report['weighted avg']['f1-score']
    print(f"\nMacro F1-Score: [{macro_f1:.4f}]")
    print(f"Weighted F1-Score: [{weighted_f1:.4f}]")
    
    # Plot prediction sample 
    plot_prediction_samples(model, test_gen, batch_images, samples_results_save_path, num_samples, no_subplot_x_axes, no_subplot_y_axes)
    
    # Save results to JSON
    results = {'Test_Metrics': test_results,
               'Macro_F1_Score': float(macro_f1),
               'Weighted_F1_Score': float(weighted_f1),
               'Detailed_Report': detailed_report,
               'Class_Names': ['Chickenpox', 'Cowpox', 'Healthy', 'HFMD', 'Measles', 'Monkeypox'],
               'Confusion_Matrix': cm.tolist(),
               'Model_Config': {
                   'Base_model': 'MobileNetV2',
                   'Image_size': (224,224,3),
                   'Number_Classes': 6,
                   'Epochs_Frozen': 300,
                   'Epochs_Fine': 300,
                   'Initial_Lr_For_Transfer_Learning': 0.001,
                   'Initial_Lr_For_Fine_Tuning': 0.0000001}}
    
    # Save results JSON
    with open(os.path.join(eval_results_save_path, 'skin_disease_results.json'), 'w') as file:
        json.dump(results, file, indent=4)
    
    return results

# %%
results = load_best_model_and_evaluate(new_model=new_model,
                             final_model_save_path='/kaggle/working/weights/final_fine_tune_best.h5',
                             test_gen=test_gen, 
                             eval_results_save_path='/kaggle/working/', 
                             batch_images=32,
                             samples_results_save_path='/kaggle/working/', 
                             num_samples=20, 
                             no_subplot_x_axes=4,
                             no_subplot_y_axes=5)
# Out:
# Best Model Load successfully.
# Model Evaluation Has Been Started...........................
# ============================================================
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - accuracy: 0.9913 - loss: 0.0252 - precision: 0.9925 - recall: 0.9913 - top_2_accuracy: 1.0000
#
# Test Results:
# Accuracy: 0.9935
# Loss: 0.0208
# Precision: 0.9952
# Recall: 0.9935
# Top_2_accuracy: 1.0000
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 8s 240ms/step
# ============================================================
# Classification Report
# ============================================================
#               precision    recall  f1-score   support
#
#   Chickenpox       0.18      0.18      0.18       103
#       Cowpox       0.16      0.16      0.16       102
#         HFMD       0.13      0.14      0.14       103
#      Healthy       0.17      0.17      0.17       104
#      Measles       0.23      0.23      0.23       104
#    Monkeypox       0.17      0.17      0.17       104
#
#     accuracy                           0.18       620
#    macro avg       0.18      0.18      0.18       620
# weighted avg       0.18      0.18      0.18       620
# Macro F1-Score: [0.1757]
# Weighted F1-Score: [0.1758]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# /tmp/ipykernel_35/1440102124.py:66: UserWarning: The figure layout has changed to tight
#   plt.tight_layout()
# Accuracy on displayed samples: [1.000] [20/20]
